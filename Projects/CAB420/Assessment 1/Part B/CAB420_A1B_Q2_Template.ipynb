# %% [markdown]
# # CAB420 Assignment 1B Question 2: Template
#
# ## Overview
#
# This notebook provides a helper function to load in the Oxford-IIIT Pets dataset suitable for classification and semantic segmentation, to help with Assignment 1B, Question 2.
#
# It also provides an example of how to load in the MobileNetV3Small Network which you are required to fine tune for the second part of the question.
#
# Please read the comments and instructions within this notebook. It has been carefully designed to help you with many of the tasks required.
#
# Please make sure you read the assignment brief on canvas, and check the FAQ for other information.

# %%
# 1. Imports
# !pip install --upgrade tensorflow_datasets
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import matplotlib.pyplot as plt
from matplotlib import gridspec
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization, SpatialDropout2D, Activation, Flatten, GlobalAveragePooling2D
from keras.models import Model
import numpy as np
import pandas as pd
import glob
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Clear the session at the beginning to start with a clean slate
tf.keras.backend.clear_session()
# Out:
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (5.29.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (1.17.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (3.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.13.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2025.4.26)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow_datasets) (25.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow_datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow_datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.70.0)

# %% [markdown]
# ### Data loading and pre-processing functions
#
# We first provide some helper functions to format the data in the way we need. You shouldn't need to change these, though you are welcome to if you like.
#
# One thing you may want to do is create additional augmentation functions, and the ``flip_lr_augmentation`` function below could be used as a template to create additional augmentation types.

# %%
# 2. Def Functions
# Template Functions (Unmodified)
def preprocess_segmentation_mask(segmentation_mask):
    """preprocess the semgentation mask

    The original segmentation mask has three categories.
      foreground, background and outline
    This function will just convert it to foreground and background

    The original segmentation mask is also 1-index, so will convert it
    to 0-index.

    the original mask is represented as:
    1 - edge of dog/cat and things like leashes etc.
    2 - background
    3 - foreground

    we want to just merge the edges and foreground of the doggo/catto, and
    then treat it as a binary semantic segmentation task.
    To achieve this, we will just subtract two, converting to values of [-1, 0, 1],
    and then apply the abs function to convert the -1 values (edges) to the foreground.

    Will also convert it to 32 bit float which will be needed for working with tf.

    Why am I doing it this way?
     A reasonable question. Initially I tried to do it with just normal array indexing,
     but this is a bit more work since the mask is a tensorflow tensor and not a np array.
     We could alternatively convert it to an array, perform indexing and then map it back,
     but this would have a performance overhead, which wouldn't be a big deal, but still.
     With all that being said, I am doing it for you, so you don't have to.

    Args:
      segmentation_mask (array):
        original segmentation mask

    Returns:
      preprocessed segmentation_mask
    """
    return tf.abs(tf.cast(segmentation_mask, tf.float32) - 2)

def return_image_label_mask(ds_out):
    """ function to return image, class label and segmentation mask

    The original dataset contains additional information, such as the filename and
    the species. We don't care about any of that for this work, so will
    discard them and just keep the original image as our input, and then
    a tuple of our outputs that will be the class label and the semantic
    segmentation mask.

    Whilst we are here, we will also preprocess the segmentation mask.

    Args:
      ds_out: dict
        original dataset output

    Returns:
       RGB image
       tuple of class label and preprocessed segmentation mask
    """
    # preprocess the segmentation mask
    seg_mask =  preprocess_segmentation_mask(ds_out['segmentation_mask'])
    image = tf.cast(ds_out['image'], tf.float32)
    # image = standardise_image(image)
    return image, (ds_out['label'], seg_mask)

def mobilenet_preprocess_image(image):
    """Apply preprocessing that is suitable for MobileNetV3.

    Simply scales to ranges [-1, 1]


    you should use this preprocessing for both your model and the mobilenet model
    """
    image = (image - 127.5) / 255.0
    return image

def unprocess_image(image):
    """ undo preprocessing above so can plot images"""
    image = image * 255.0 + 127.5
    return image

def preprocess_and_resize(image, output, image_size):
    """apply preprocessing steps above to images and resize images and maps

    Each image in the dataset is of a different size. The resizing will make sure
    each image is the same size.
    """
    # resize the image and the semantic segmentation mask
    image = tf.image.resize(image, [image_size, image_size])
    image = mobilenet_preprocess_image(image)
    mask = tf.image.resize(output[1], [image_size, image_size])
    return image, (output[0], mask)

def flip_lr_augmentation(image, output, flip_lr_prob):
    """ function to return perform left-right flip augmentation

    The function will flip the image along the left-right axis with
    a defined probability.
    """

    # randomly sample a value between 0 and 1
    uniform_sample = tf.random.uniform([], minval=0, maxval=1)
    # perform flip_lr with probability given by flip_lr_prob
    flip_lr_cond = tf.math.less(uniform_sample, flip_lr_prob)
    # output is a tuple of (class, segmentation_mask), pull out the segmentation mask
    seg = output[1]

    # wrapper fn for when we do the flip
    def flip():
        flipped_image = tf.image.flip_left_right(image)
        flipped_seg = tf.image.flip_left_right(seg)
        return flipped_image, flipped_seg

    # wrapper fn for when we do NOT flip
    def no_flip():
        return image, seg

    # apply augmentation
    image, seg = tf.cond(flip_lr_cond, flip, no_flip)
    # return the image, and output
    return image, (output[0], seg)

def select_tasks(image, output, classification=True, segmentation=True):
    """select the tasks to include the data

    By default for each input there are two outputs. This function allows
    you to select which outputs to use, so the problem can be reduced to a
    single task problem for initial experimenting.
    """
    # both tasks
    if classification and segmentation:
        return image, output
    # just classification
    elif classification:
        return image, output[0]
    # just segmentation
    elif segmentation:
        return image, output[1]
    # neither task, doesn't really make sense, so return the image
    # for a self-supervised task
    else:
        return image, image

class TrainForTime(keras.callbacks.Callback):
    """callback to terminate training after a time limit is reached

    Can be used to control how long training runs for, and will terminate
    training once a specified time limit is reached.
    """
    def __init__(
        self,
        train_time_mins=15,
    ):
        super().__init__()

        self.train_time_mins = train_time_mins
        self.epochs = 0
        self.train_time = 0
        self.end_early = False

    def on_train_begin(self, logs=None):
        # save the start time
        self.start_time = tf.timestamp()

    def on_epoch_end(self, epoch, logs=None):
        self.epochs += 1
        current_time = tf.timestamp()
        training_time = (current_time - self.start_time)
        if (training_time / 60) > self.train_time_mins:
            self.train_time = current_time - self.start_time
            self.model.stop_training = True
            self.end_early = True

    def on_train_end(self, logs=None):
        if self.end_early:
            print('training time exceeded and ending early')
            print(f'training ended on epoch {self.epochs}')
            print(f'training time = {self.train_time / 60} mins')

def load_oxford_pets(split,
                     batch_size=233,
                     classification=True,
                     segmentation=True,
                     shuffle=True,
                     augment=True,
                     image_size=300):
    """Load Oxford pets dataset for Assignment 1B

    Function handles loading of data for 1b, included processing of images and
    semantic segmentation masks. This function will
    organise the tensorflow dataset to return an output that is a tuple, where
    the tuple will be (classification_labels, segmentation_masks).

    Parameters
    ----------
    split : string
        either train, val or test string
    classification : bool
        whether to include classification labels
    segmentation : bool
        whether to include semantic segmentation masks
    batch_size : int
        size of batches to use
    shuffle : bool
        whether to shuffle the dataset (WILL ONLY APPLY TO TRAIN)
    augment : bool
        whether to augment the dataset (WILL ONLY APPLY TO TRAIN)
    image_size : int
        new image size

    Returns
    -------
       tf.Dataset containing the Oxford pets dataset
    """
    # lets do some error checking first
    # Check fior a valid dataset split, this must be train or test
    if (split != 'train') and (split != 'val') and (split != 'test'):
        raise ValueError('Arg for split must be either \'train\' or \'test\'')
    if (not classification) and (not segmentation):
        print("WARNING: One of the tasks (classification and segmentation) must be selected")
        print("Setting both to enabled")
        classification = True
        segmentation = True

    # check that if using the val split, shuffle if false. If not, print a warning and force shuffle to be false
    if (split == 'val') and shuffle:
        print("WARNING: shuffle is set to true, but have specified split to be \'val\'")
        print('The shuffle argument will be ignored')
        shuffle = False

    # check that if using the test split, shuffle if false. If not, print a warning and force shuffle to be false
    if (split == 'test') and shuffle:
        print("WARNING: shuffle is set to true, but have specified split to be \'test\'")
        print('The shuffle argument will be ignored')
        shuffle = False

    # check that if using the val split, augment if false. If not, print a warning and force augment to be false
    if (split == 'val') and augment:
        print("WARNING: augment is set to true, but have specified split to be \'val\'")
        print('The augment argument will be ignored')
        augment = False

    # check that if using the test split, augment if false. If not, print a warning and force augment to be false
    if (split == 'test') and augment:
        print("WARNING: augment is set to true, but have specified split to be \'test\'")
        print('The augment argument will be ignored')
        augment = False

    # the dataset by default only has train and test splits. If val is requested, pull the first 30% of the test set
    if (split == 'val'):
        split = 'test[:30%]'
    # the test set then becomes the remaining 70% of the original test set
    elif (split == 'test'):
        split = 'test[30%:]'

    # now start loading the dataset
    ds = tfds.load('oxford_iiit_pet',
                   split=split,
                   with_info=False)

    # remove unnecessary dataset info
    ds = ds.map(return_image_label_mask)

    # augmentation
    # only apply if in the training split and augment has been set to True
    if split == 'train' and augment:
        # apply a left-right flip with 50% probability
        flip_lr_prob = 0.5
        # flip operation
        ds = ds.map(lambda inp, out: flip_lr_augmentation(inp, out, flip_lr_prob), num_parallel_calls=tf.data.AUTOTUNE)

        # more augmentation operations could go here .....

    # Final processing of the data
    # here we will resize the data, and add the preprocessing that is needed for compatability with the mobilenet models.
    ds = ds.map(lambda inp, out: preprocess_and_resize(inp, out, image_size))

    # and now remove any tasks that we don't want. Note that we call this last as it means that all the other functions
    # can safely assume that data for both tasks is in the dataset
    ds = ds.map(lambda inp, out: select_tasks(inp, out, classification, segmentation))

    # if in the training split, and shuffle is true, shuffle the data
    if split == 'train' and shuffle:
        ds = ds.shuffle(1000)

    # return the loaded and processed dataset
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Weekly Example Functions (Unmodified Logic, Adjusted for Import)
def conv_block(inputs, filters, spatial_dropout=0.0, max_pool=True):
    x = keras.layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    x = keras.layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation=None)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    if (spatial_dropout > 0.0):
        x = keras.layers.SpatialDropout2D(spatial_dropout)(x)
    if (max_pool == True):
        x = keras.layers.MaxPool2D(pool_size=(2, 2))(x)
    return x

def fc_block(inputs, size, dropout):
    x = keras.layers.Dense(size, activation=None)(inputs)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    if (dropout > 0.0):
        x = keras.layers.Dropout(dropout)(x)
    return x

def vgg_net(inputs, filters, fc, spatial_dropout=0.0, dropout=0.0):
    x = inputs
    for idx, i in enumerate(filters):
        x = conv_block(x, i, spatial_dropout, not (idx==len(filters) - 1))
    x = keras.layers.Flatten()(x)
    for i in fc:
        x = fc_block(x, i, dropout)
    return x

# %% [markdown]
# ### Data Loader
#
# We will now put the above functions together into a data loader that we can use to feed directly to the network. You can you this directly as it is. However, you may modify it to add some additional functionality such as further data augmentations.

# %%
def load_oxford_pets(split,
                     batch_size=233,
                     classification=True,
                     segmentation=True,
                     shuffle=True,
                     augment=True,
                     image_size=300):
    """Load Oxford pets dataset for Assignment 1B

    Function handles loading of data for 1b, included processing of images and
    semantic segmentation masks. This function will
    organise the tensorflow dataset to return an output that is a tuple, where
    the tuple will be (classification_labels, segmentation_masks).

    Parameters
    ----------
    split : string
        either train, val or test string
    classification : bool
        whether to include classification labels
    segmentation : bool
        whether to include semantic segmentation masks
    batch_size : int
        size of batches to use
    shuffle : bool
        whether to shuffle the dataset (WILL ONLY APPLY TO TRAIN)
    augment : bool
        whether to augment the dataset (WILL ONLY APPLY TO TRAIN)
    image_size : int
        new image size

    Returns
    -------
       tf.Dataset containing the Oxford pets dataset
    """
    # lets do some error checking first
    # Check fior a valid dataset split, this must be train or test
    if (split != 'train') and (split != 'val') and (split != 'test'):
        raise ValueError('Arg for split must be either \'train\' or \'test\'')
    if (not classification) and (not segmentation):
        print("WARNING: One of the tasks (classification and segmentation) must be selected")
        print("Setting both to enabled")
        classification = True
        segmentation = True

    # check that if using the val split, shuffle if false. If not, print a warning and force shuffle to be false
    if (split == 'val') and shuffle:
        print("WARNING: shuffle is set to true, but have specified split to be \'val\'")
        print('The shuffle argument will be ignored')
        shuffle = False

    # check that if using the test split, shuffle if false. If not, print a warning and force shuffle to be false
    if (split == 'test') and shuffle:
        print("WARNING: shuffle is set to true, but have specified split to be \'test\'")
        print('The shuffle argument will be ignored')
        shuffle = False

    # check that if using the val split, augment if false. If not, print a warning and force augment to be false
    if (split == 'val') and augment:
        print("WARNING: augment is set to true, but have specified split to be \'val\'")
        print('The augment argument will be ignored')
        augment = False

    # check that if using the test split, augment if false. If not, print a warning and force augment to be false
    if (split == 'test') and augment:
        print("WARNING: augment is set to true, but have specified split to be \'test\'")
        print('The augment argument will be ignored')
        augment = False

    # the dataset by default only has train and test splits. If val is requested, pull the first 30% of the test set
    if (split == 'val'):
        split = 'test[:30%]'
    # the test set then becomes the remaining 70% of the original test set
    elif (split == 'test'):
        split = 'test[30%:]'

    # now start loading the dataset
    ds = tfds.load('oxford_iiit_pet',
                   split=split,
                   with_info=False)

    # remove unnecessary dataset info
    ds = ds.map(return_image_label_mask)

    # augmentation
    # only apply if in the training split and augment has been set to True
    if split == 'train' and augment:
        # apply a left-right flip with 50% probability
        flip_lr_prob = 0.5
        # flip operation
        ds = ds.map(lambda inp, out: flip_lr_augmentation(inp, out, flip_lr_prob), num_parallel_calls=tf.data.AUTOTUNE)

        # more augmentation operations could go here .....

    # Final processing of the data
    # here we will resize the data, and add the preprocessing that is needed for compatability with the mobilenet models.
    ds = ds.map(lambda inp, out: preprocess_and_resize(inp, out, image_size))

    # and now remove any tasks that we don't want. Note that we call this last as it means that all the other functions
    # can safely assume that data for both tasks is in the dataset
    ds = ds.map(lambda inp, out: select_tasks(inp, out, classification, segmentation))

    # if in the training split, and shuffle is true, shuffle the data
    if split == 'train' and shuffle:
        ds = ds.shuffle(1000)

    # return the loaded and processed dataset
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Testing the provided data loader.
#
# We'll now test the data loader and plot some examples to confirm it's working. **NOTE: some poor defaults are specified below for image size and batch size. Set these to something more appropriate.**

# %%
# testing the data loader and plotting some images.
# NOTE: the image size set here is all but definitely too large. You will need
# to chage this yourself to something that is suitable given your constraints
# NOTE: The batch size is also too large. This done on purpose force you to
# pick a suitable batch size yourself
image_size = 300
batch_size = 273
# load training data, note that shuffle and augment are true
train_class_seg = load_oxford_pets('train', classification=True, segmentation=True, shuffle=True, augment=True,
                                   batch_size=batch_size, image_size=image_size)
# load validation data, note that shuffle and augment are false (though if they weren't, the data loader would force these to be false)
val_class_seg = load_oxford_pets('val', classification=True, segmentation=True, shuffle=False, augment=False,
                                 batch_size=batch_size, image_size=image_size)
# load testing data, note that shuffle and augment are false (though if they weren't, the data loader would force these to be false)
test_class_seg = load_oxford_pets('test', classification=True, segmentation=True, shuffle=False, augment=False,
                                  batch_size=batch_size, image_size=image_size)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_iiit_pet/4.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/incomplete.TJCG4T_4.0.0/oxford_iiit_pet-train.tfrecord*...…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/incomplete.TJCG4T_4.0.0/oxford_iiit_pet-test.tfrecord*...:…
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0. Subsequent calls will reuse this data.

# %%
# lets plot a few now to see some good kittens/doggos
fig, axs = plt.subplots(2, 3, figsize=(8, 4), layout="constrained")
num_plot = 3
i = 0

# each sample of our dataset will be of the format
# image, outputs
# where outputs[0] = label
#       outputs[1] = segmentation mask
#
#
# lets get a single batch, and plot just a few of them
for image, output in train_class_seg.take(1).as_numpy_iterator():
    for i in range(num_plot):
        im = axs[0, i].imshow(np.squeeze(unprocess_image(image[i, ...])) / 255.0)
        axs[0, i].set_title(output[0][i])
        axs[0, i].axis('off')
        im = axs[1, i].imshow(np.squeeze(output[1][i, ...]))
        axs[1, i].axis('off')

        print(output[1].shape)
        i += 1
        if i >= num_plot:
            break

plt.savefig('doggos_cattos.png')
# Out:
# (273, 300, 300, 1)
# (273, 300, 300, 1)
# (273, 300, 300, 1)

# %% [markdown]
# The images are showing correctly.
#
# **NOTE: You can ignore the JPEG wearning.**
#
# We can use the ``classification`` and ``segmentation`` flags to pull out just one output as well, as the below demonstrates.

# %%
# classification only; classification = True, segmentation = False (note batch size is 1 here)
train_class_only = load_oxford_pets('train', classification=True, segmentation=False, shuffle=True, augment=True, batch_size=1, image_size=image_size)
# segmentation only; classification = False, segmentation = True (note batch size is 1 here)
train_seg_only = load_oxford_pets('train', classification=False, segmentation=True, shuffle=True, augment=True, batch_size=1, image_size=image_size)

# test the classification only dataset
# pull out one element
inp, out = next(iter(train_class_only))
# print the output
print(out.numpy())

# test the segmentation only dataset
# pull out one element
inp, out = next(iter(train_seg_only))
# print just the output shape for the segmentation output
print(out.numpy().shape)
# Out:
# [27]
# (1, 300, 300, 1)

# %% [markdown]
# While for the question you do need to train networks to do both tasks simultaenously, when you starting playing with the problem it might be easier to get things working for one task, and then add the second.
#
# ### Loading MobileNetV3Small base for fine tuning
#
# This model can be loaded directly from keras. By default, the model we download will be pre-trained on Imagenet dataset.
#
# Note that we will need to set the preprocessing option when loading this base network to False. This is because the `include_preprocessing` step is implemented in the Datasets we defined above.
#
# We also set `include_top=False`, to avoid loading our model with the final Dense classification layer which is used for the original Imagenet model.
#
# More details are available in the keras documentation [here](https://keras.io/api/applications/mobilenet/).

# %%
mobile_base = keras.applications.MobileNetV3Small(input_shape=(image_size, image_size, 3),
                                                  include_top=False,
                                                  include_preprocessing=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/applications/mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# For this task, can ignore the input_shape warning, though it is important to keep in mind the difference in size of data used for the pre-trained model and our data may have an impact on our model (what that impact might be is for you to investigate :) ). Depending on what input shape you select you may also be able to eliminate this.
#
# For more information on fine-tuning models, can refer to many of the examples from class, or the [Keras documentation](https://keras.io/guides/transfer_learning/)

# %% [markdown]
# ## Question 2 Template
#
# The following provides a starting point for your solution, and some suggestions on how to proceed.
#
# **PLEASE READ THE COMMENTS CAREFULLY** There are a number of tips around how to proceed, and things to look out for.

# %%
# 3. Data Loading
image_size = 128  # Reduced to lower memory usage
batch_size = 64   # Reduced to manage compute resources
train_class_seg = load_oxford_pets('train', classification=True, segmentation=True, shuffle=True, augment=True, batch_size=batch_size, image_size=image_size)
val_class_seg = load_oxford_pets('val', classification=True, segmentation=True, shuffle=False, augment=False, batch_size=batch_size, image_size=image_size)
test_class_seg = load_oxford_pets('test', classification=True, segmentation=True, shuffle=False, augment=False, batch_size=batch_size, image_size=image_size)
train_class_seg_ns = load_oxford_pets('train', classification=True, segmentation=True, shuffle=False, augment=True, batch_size=batch_size, image_size=image_size)

# Plot a few samples to verify data loading
fig, axs = plt.subplots(2, 3, figsize=(10, 4), layout="constrained")
num_plot = 3
i = 0
for image, output in train_class_seg.take(1).as_numpy_iterator():
    for i in range(num_plot):
        im = axs[0, i].imshow(np.squeeze(unprocess_image(image[i, ...])) / 255.0)
        axs[0, i].set_title(output[0][i])
        axs[0, i].axis('off')
        im = axs[1, i].imshow(np.squeeze(output[1][i, ...]))
        axs[1, i].axis('off')
        i += 1
        if i >= num_plot:
            break
plt.savefig('doggos_cattos.png')

# %%
#
# From-scratch DCNN
#
# Put your from-scratch DCNN here. This network will have one input (the input image), and two outputs (the class, and the segmentation map). You can
# think of your model as having three components:
#  - A backbone, which is going to take your input and encode that. This will possibly be collection of (probably mostly) 2D convolution layers
#    and max pooling layers (and for which you may be able to find something fairly fit for purpose in lecture or prac examples).
#  - A classification head, which will take the backbone output and via one or more dense layers do the classification task. This will likely only
#    be a few layers at most.
#  - A decoder head, which will do the semantic segmentation. This will look a lot like the back half of an autoencoder.
#
# As usual, the network does not need to be overly complex, but you will need to briefly explain your selection of this model, and you should avoid
# networks so simple that they perform very badly.
#
# Take note of the order that the outputs appear in the data loader. The data loader will give you (classification_output, segmentation_output), so
# your network should have the outputs in the same order, and your losses should also be in the same order. With your losses, note that:
# * For the classification task ground truth data is being given as class labels, so you should use Sparse Categorical Cross Entropy.
# * For the segmentation loss, there are a few options you could use, but a good starting point is simply binary cross entropy, essentially
#   every pixel is a binary classification task (foreground or background)
# * The order of your losses is critical. The dataset object will give you (classification_targets, segmentation_targets). This means that you're
#   network should it's outputs, and loss functions, in the same order - if you get this order wrong you will get weird errors
#
# When first developing your model, you may want to start by getting a single output of the network going, and then adding the second output. For
# example, you may build a network with the image input and the just the classification head, get that running, and then add the decoder head. You can
# use the classification and segmentation flags in the data loader to turn off one of the outputs.

# For model training, we have provided a callback, TrainForTime, which will terminate training after some time limit is reached. You could use this
# as follows:
#
#   train_time = 15 # 15-minute training limit
#   my_awesome_model.fit(train_class_seg, epochs=epochs, verbose=True, validation_data=val_class_seg, callbacks=[TrainForTime(train_time)])
#
# You don't have to use this, but you may wish to use this to ensure training doesn't take too long.
# Note that if you don't train until convergence, you will need to explain what you observe with training and what the implications of this are.

# Build the from-scratch model with a shared backbone, classification head, and segmentation head

train_time = 15

# 4. From-Scratch DCNN
# Build the from-scratch model with a shared backbone, classification head, and segmentation head
input_shape = (image_size, image_size, 3)
inputs = Input(shape=input_shape)
conv1 = conv_block(inputs, 32, spatial_dropout=0.2, max_pool=True)  # (64, 64, 32)
conv2 = conv_block(conv1, 64, spatial_dropout=0.2, max_pool=True)   # (32, 32, 64)
conv3 = conv_block(conv2, 128, spatial_dropout=0.2, max_pool=True)  # (16, 16, 128)
class_head = GlobalAveragePooling2D()(conv3)  # (128,)
class_output = Dense(37, activation='softmax', name='class_output')(class_head)
seg_head = UpSampling2D((2, 2))(conv3)  # (32, 32, 128)
seg_head = concatenate([seg_head, conv2])  # (32, 32, 192)
seg_head = conv_block(seg_head, 64, spatial_dropout=0.2, max_pool=False)  # (32, 32, 64)
seg_head = UpSampling2D((2, 2))(seg_head)  # (64, 64, 64)
seg_head = concatenate([seg_head, conv1])  # (64, 64, 96)
seg_head = conv_block(seg_head, 32, spatial_dropout=0.2, max_pool=False)  # (64, 64, 32)
seg_head = UpSampling2D((2, 2))(seg_head)  # (128, 128, 32)
seg_head = Conv2D(16, (3, 3), padding='same', activation='relu')(seg_head)  # (128, 128, 16)
seg_head = BatchNormalization()(seg_head)
seg_output = Conv2D(1, (3, 3), padding='same', activation='sigmoid', name='seg_output')(seg_head)  # (128, 128, 1)
# 15-min
from_scratch_model = Model(inputs=inputs, outputs=[class_output, seg_output])
from_scratch_model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss=['sparse_categorical_crossentropy', 'binary_crossentropy'], loss_weights=[1.0, 1.0], metrics={'class_output': 'accuracy', 'seg_output': 'accuracy'})
# Train the Model
from_scratch_model.fit(train_class_seg, epochs=200, verbose=True, validation_data=val_class_seg, callbacks=[TrainForTime(train_time)])
# Out:
# Epoch 1/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 43s 406ms/step - class_output_accuracy: 0.0350 - class_output_loss: 3.7988 - loss: 4.4827 - seg_output_accuracy: 0.5933 - seg_output_loss: 0.6838 - val_class_output_accuracy: 0.0327 - val_class_output_loss: 3.6114 - val_loss: 4.2304 - val_seg_output_accuracy: 0.6904 - val_seg_output_loss: 0.6197
# Epoch 2/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - class_output_accuracy: 0.0482 - class_output_loss: 3.5806 - loss: 4.1406 - seg_output_accuracy: 0.7019 - seg_output_loss: 0.5600 - val_class_output_accuracy: 0.0400 - val_class_output_loss: 3.6554 - val_loss: 4.2865 - val_seg_output_accuracy: 0.5768 - val_seg_output_loss: 0.6328
# Epoch 3/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 286ms/step - class_output_accuracy: 0.0590 - class_output_loss: 3.5318 - loss: 4.0611 - seg_output_accuracy: 0.7292 - seg_output_loss: 0.5293 - val_class_output_accuracy: 0.0254 - val_class_output_loss: 3.6966 - val_loss: 4.3325 - val_seg_output_accuracy: 0.5810 - val_seg_output_loss: 0.6374
# Epoch 4/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 288ms/step - class_output_accuracy: 0.0668 - class_output_loss: 3.4873 - loss: 4.0016 - seg_output_accuracy: 0.7442 - seg_output_loss: 0.5143 - val_class_output_accuracy: 0.0300 - val_class_output_loss: 3.7753 - val_loss: 4.6146 - val_seg_output_accuracy: 0.5770 - val_seg_output_loss: 0.8437
# Epoch 5/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 273ms/step - class_output_accuracy: 0.0756 - class_output_loss: 3.4735 - loss: 3.9817 - seg_output_accuracy: 0.7471 - seg_output_loss: 0.5082 - val_class_output_accuracy: 0.0291 - val_class_output_loss: 3.8163 - val_loss: 4.4355 - val_seg_output_accuracy: 0.6258 - val_seg_output_loss: 0.6171
# Epoch 6/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - class_output_accuracy: 0.0769 - class_output_loss: 3.4343 - loss: 3.9148 - seg_output_accuracy: 0.7681 - seg_output_loss: 0.4805 - val_class_output_accuracy: 0.0400 - val_class_output_loss: 3.7551 - val_loss: 4.3454 - val_seg_output_accuracy: 0.6746 - val_seg_output_loss: 0.5891
# Epoch 7/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 226ms/step - class_output_accuracy: 0.0868 - class_output_loss: 3.3879 - loss: 3.8633 - seg_output_accuracy: 0.7703 - seg_output_loss: 0.4755 - val_class_output_accuracy: 0.0581 - val_class_output_loss: 3.6444 - val_loss: 4.2376 - val_seg_output_accuracy: 0.7021 - val_seg_output_loss: 0.5871
# Epoch 8/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - class_output_accuracy: 0.0966 - class_output_loss: 3.3535 - loss: 3.8128 - seg_output_accuracy: 0.7825 - seg_output_loss: 0.4593 - val_class_output_accuracy: 0.0436 - val_class_output_loss: 3.6323 - val_loss: 4.0830 - val_seg_output_accuracy: 0.7849 - val_seg_output_loss: 0.4558
# Epoch 9/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 285ms/step - class_output_accuracy: 0.1012 - class_output_loss: 3.3022 - loss: 3.7505 - seg_output_accuracy: 0.7902 - seg_output_loss: 0.4484 - val_class_output_accuracy: 0.0763 - val_class_output_loss: 3.5499 - val_loss: 3.9743 - val_seg_output_accuracy: 0.7978 - val_seg_output_loss: 0.4315
# Epoch 10/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 290ms/step - class_output_accuracy: 0.1142 - class_output_loss: 3.2251 - loss: 3.6429 - seg_output_accuracy: 0.8078 - seg_output_loss: 0.4178 - val_class_output_accuracy: 0.0917 - val_class_output_loss: 3.3700 - val_loss: 3.7994 - val_seg_output_accuracy: 0.7952 - val_seg_output_loss: 0.4365
# Epoch 11/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - class_output_accuracy: 0.1313 - class_output_loss: 3.2161 - loss: 3.6368 - seg_output_accuracy: 0.8068 - seg_output_loss: 0.4207 - val_class_output_accuracy: 0.1017 - val_class_output_loss: 3.3076 - val_loss: 3.7128 - val_seg_output_accuracy: 0.8076 - val_seg_output_loss: 0.4158
# Epoch 12/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - class_output_accuracy: 0.1337 - class_output_loss: 3.1650 - loss: 3.5788 - seg_output_accuracy: 0.8105 - seg_output_loss: 0.4138 - val_class_output_accuracy: 0.1126 - val_class_output_loss: 3.2035 - val_loss: 3.5828 - val_seg_output_accuracy: 0.8276 - val_seg_output_loss: 0.3886
# Epoch 13/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 246ms/step - class_output_accuracy: 0.1494 - class_output_loss: 3.1274 - loss: 3.5307 - seg_output_accuracy: 0.8156 - seg_output_loss: 0.4034 - val_class_output_accuracy: 0.1226 - val_class_output_loss: 3.1943 - val_loss: 3.5789 - val_seg_output_accuracy: 0.8194 - val_seg_output_loss: 0.3952
# Epoch 14/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - class_output_accuracy: 0.1491 - class_output_loss: 3.1231 - loss: 3.5242 - seg_output_accuracy: 0.8159 - seg_output_loss: 0.4012 - val_class_output_accuracy: 0.1317 - val_class_output_loss: 3.1640 - val_loss: 3.5309 - val_seg_output_accuracy: 0.8295 - val_seg_output_loss: 0.3835
# Epoch 15/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 290ms/step - class_output_accuracy: 0.1593 - class_output_loss: 3.0886 - loss: 3.4720 - seg_output_accuracy: 0.8253 - seg_output_loss: 0.3835 - val_class_output_accuracy: 0.1135 - val_class_output_loss: 3.2456 - val_loss: 3.5835 - val_seg_output_accuracy: 0.8412 - val_seg_output_loss: 0.3592
# Epoch 16/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 288ms/step - class_output_accuracy: 0.1597 - class_output_loss: 3.0397 - loss: 3.4187 - seg_output_accuracy: 0.8304 - seg_output_loss: 0.3789 - val_class_output_accuracy: 0.1444 - val_class_output_loss: 3.1033 - val_loss: 3.4651 - val_seg_output_accuracy: 0.8388 - val_seg_output_loss: 0.3658
# Epoch 17/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - class_output_accuracy: 0.1873 - class_output_loss: 2.9895 - loss: 3.3584 - seg_output_accuracy: 0.8342 - seg_output_loss: 0.3688 - val_class_output_accuracy: 0.1608 - val_class_output_loss: 3.0401 - val_loss: 3.3713 - val_seg_output_accuracy: 0.8439 - val_seg_output_loss: 0.3540
# Epoch 18/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 288ms/step - class_output_accuracy: 0.1888 - class_output_loss: 2.9735 - loss: 3.3378 - seg_output_accuracy: 0.8367 - seg_output_loss: 0.3643 - val_class_output_accuracy: 0.1671 - val_class_output_loss: 3.0238 - val_loss: 3.4139 - val_seg_output_accuracy: 0.8294 - val_seg_output_loss: 0.3894
# Epoch 19/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 232ms/step - class_output_accuracy: 0.1946 - class_output_loss: 2.9327 - loss: 3.2950 - seg_output_accuracy: 0.8381 - seg_output_loss: 0.3623 - val_class_output_accuracy: 0.1253 - val_class_output_loss: 3.1240 - val_loss: 3.4683 - val_seg_output_accuracy: 0.8464 - val_seg_output_loss: 0.3500
# Epoch 20/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 24s 272ms/step - class_output_accuracy: 0.2128 - class_output_loss: 2.8574 - loss: 3.2151 - seg_output_accuracy: 0.8404 - seg_output_loss: 0.3577 - val_class_output_accuracy: 0.1735 - val_class_output_loss: 2.9472 - val_loss: 3.2718 - val_seg_output_accuracy: 0.8557 - val_seg_output_loss: 0.3296
# Epoch 21/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 286ms/step - class_output_accuracy: 0.1957 - class_output_loss: 2.8742 - loss: 3.2245 - seg_output_accuracy: 0.8439 - seg_output_loss: 0.3503 - val_class_output_accuracy: 0.1826 - val_class_output_loss: 2.9571 - val_loss: 3.2919 - val_seg_output_accuracy: 0.8530 - val_seg_output_loss: 0.3357
# Epoch 22/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 281ms/step - class_output_accuracy: 0.2177 - class_output_loss: 2.8384 - loss: 3.1952 - seg_output_accuracy: 0.8408 - seg_output_loss: 0.3567 - val_class_output_accuracy: 0.1807 - val_class_output_loss: 2.9542 - val_loss: 3.2668 - val_seg_output_accuracy: 0.8604 - val_seg_output_loss: 0.3213
# Epoch 23/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.2243 - class_output_loss: 2.8097 - loss: 3.1610 - seg_output_accuracy: 0.8439 - seg_output_loss: 0.3513 - val_class_output_accuracy: 0.1789 - val_class_output_loss: 2.9025 - val_loss: 3.2484 - val_seg_output_accuracy: 0.8474 - val_seg_output_loss: 0.3443
# Epoch 24/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step - class_output_accuracy: 0.2350 - class_output_loss: 2.7467 - loss: 3.0907 - seg_output_accuracy: 0.8472 - seg_output_loss: 0.3440 - val_class_output_accuracy: 0.1689 - val_class_output_loss: 3.0031 - val_loss: 3.3308 - val_seg_output_accuracy: 0.8543 - val_seg_output_loss: 0.3328
# Epoch 25/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 286ms/step - class_output_accuracy: 0.2440 - class_output_loss: 2.7722 - loss: 3.1114 - seg_output_accuracy: 0.8501 - seg_output_loss: 0.3392 - val_class_output_accuracy: 0.1580 - val_class_output_loss: 3.1060 - val_loss: 3.4095 - val_seg_output_accuracy: 0.8550 - val_seg_output_loss: 0.3346
# Epoch 26/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 243ms/step - class_output_accuracy: 0.2304 - class_output_loss: 2.7360 - loss: 3.0908 - seg_output_accuracy: 0.8415 - seg_output_loss: 0.3548 - val_class_output_accuracy: 0.2035 - val_class_output_loss: 2.8471 - val_loss: 3.1707 - val_seg_output_accuracy: 0.8630 - val_seg_output_loss: 0.3167
# Epoch 27/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 287ms/step - class_output_accuracy: 0.2388 - class_output_loss: 2.7177 - loss: 3.0567 - seg_output_accuracy: 0.8509 - seg_output_loss: 0.3390 - val_class_output_accuracy: 0.1771 - val_class_output_loss: 2.9264 - val_loss: 3.2340 - val_seg_output_accuracy: 0.8620 - val_seg_output_loss: 0.3217
# Epoch 28/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 244ms/step - class_output_accuracy: 0.2663 - class_output_loss: 2.6370 - loss: 2.9799 - seg_output_accuracy: 0.8475 - seg_output_loss: 0.3429 - val_class_output_accuracy: 0.1717 - val_class_output_loss: 2.9395 - val_loss: 3.2450 - val_seg_output_accuracy: 0.8612 - val_seg_output_loss: 0.3228
# Epoch 29/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 256ms/step - class_output_accuracy: 0.2707 - class_output_loss: 2.6180 - loss: 2.9515 - seg_output_accuracy: 0.8534 - seg_output_loss: 0.3336 - val_class_output_accuracy: 0.1871 - val_class_output_loss: 2.9807 - val_loss: 3.2653 - val_seg_output_accuracy: 0.8680 - val_seg_output_loss: 0.3062
# Epoch 30/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 251ms/step - class_output_accuracy: 0.2610 - class_output_loss: 2.6588 - loss: 2.9882 - seg_output_accuracy: 0.8557 - seg_output_loss: 0.3295 - val_class_output_accuracy: 0.2216 - val_class_output_loss: 2.8046 - val_loss: 3.1061 - val_seg_output_accuracy: 0.8672 - val_seg_output_loss: 0.3063
# Epoch 31/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 290ms/step - class_output_accuracy: 0.2603 - class_output_loss: 2.6254 - loss: 2.9556 - seg_output_accuracy: 0.8540 - seg_output_loss: 0.3302 - val_class_output_accuracy: 0.1644 - val_class_output_loss: 2.9390 - val_loss: 3.2654 - val_seg_output_accuracy: 0.8491 - val_seg_output_loss: 0.3405
# Epoch 32/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - class_output_accuracy: 0.2717 - class_output_loss: 2.5998 - loss: 2.9230 - seg_output_accuracy: 0.8578 - seg_output_loss: 0.3232 - val_class_output_accuracy: 0.2234 - val_class_output_loss: 2.7877 - val_loss: 3.0776 - val_seg_output_accuracy: 0.8689 - val_seg_output_loss: 0.3050
# Epoch 33/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 268ms/step - class_output_accuracy: 0.2696 - class_output_loss: 2.5984 - loss: 2.9264 - seg_output_accuracy: 0.8551 - seg_output_loss: 0.3281 - val_class_output_accuracy: 0.1935 - val_class_output_loss: 2.8864 - val_loss: 3.1590 - val_seg_output_accuracy: 0.8742 - val_seg_output_loss: 0.2929
# Epoch 34/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 267ms/step - class_output_accuracy: 0.2883 - class_output_loss: 2.5140 - loss: 2.8315 - seg_output_accuracy: 0.8603 - seg_output_loss: 0.3175 - val_class_output_accuracy: 0.2452 - val_class_output_loss: 2.6608 - val_loss: 2.9581 - val_seg_output_accuracy: 0.8735 - val_seg_output_loss: 0.2975
# Epoch 35/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 268ms/step - class_output_accuracy: 0.3194 - class_output_loss: 2.4642 - loss: 2.7878 - seg_output_accuracy: 0.8578 - seg_output_loss: 0.3236 - val_class_output_accuracy: 0.2280 - val_class_output_loss: 2.7489 - val_loss: 3.0875 - val_seg_output_accuracy: 0.8510 - val_seg_output_loss: 0.3408
# Epoch 36/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - class_output_accuracy: 0.2879 - class_output_loss: 2.4950 - loss: 2.8155 - seg_output_accuracy: 0.8587 - seg_output_loss: 0.3205 - val_class_output_accuracy: 0.2334 - val_class_output_loss: 2.7133 - val_loss: 3.0069 - val_seg_output_accuracy: 0.8748 - val_seg_output_loss: 0.2960
# Epoch 37/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 248ms/step - class_output_accuracy: 0.3040 - class_output_loss: 2.4786 - loss: 2.7929 - seg_output_accuracy: 0.8610 - seg_output_loss: 0.3143 - val_class_output_accuracy: 0.2207 - val_class_output_loss: 2.7481 - val_loss: 3.0452 - val_seg_output_accuracy: 0.8684 - val_seg_output_loss: 0.3062
# Epoch 38/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - class_output_accuracy: 0.3422 - class_output_loss: 2.4062 - loss: 2.7211 - seg_output_accuracy: 0.8612 - seg_output_loss: 0.3150 - val_class_output_accuracy: 0.2371 - val_class_output_loss: 2.6996 - val_loss: 3.0392 - val_seg_output_accuracy: 0.8495 - val_seg_output_loss: 0.3441
# Epoch 39/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 291ms/step - class_output_accuracy: 0.3092 - class_output_loss: 2.4162 - loss: 2.7308 - seg_output_accuracy: 0.8617 - seg_output_loss: 0.3147 - val_class_output_accuracy: 0.2543 - val_class_output_loss: 2.6585 - val_loss: 2.9303 - val_seg_output_accuracy: 0.8763 - val_seg_output_loss: 0.2891
# Epoch 40/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - class_output_accuracy: 0.3021 - class_output_loss: 2.4018 - loss: 2.7150 - seg_output_accuracy: 0.8631 - seg_output_loss: 0.3132 - val_class_output_accuracy: 0.2470 - val_class_output_loss: 2.6249 - val_loss: 2.9044 - val_seg_output_accuracy: 0.8774 - val_seg_output_loss: 0.2840
# Epoch 41/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 292ms/step - class_output_accuracy: 0.3181 - class_output_loss: 2.4167 - loss: 2.7296 - seg_output_accuracy: 0.8616 - seg_output_loss: 0.3128 - val_class_output_accuracy: 0.2325 - val_class_output_loss: 2.7639 - val_loss: 3.0860 - val_seg_output_accuracy: 0.8534 - val_seg_output_loss: 0.3478
# Epoch 42/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 293ms/step - class_output_accuracy: 0.3272 - class_output_loss: 2.4002 - loss: 2.7108 - seg_output_accuracy: 0.8636 - seg_output_loss: 0.3105 - val_class_output_accuracy: 0.2225 - val_class_output_loss: 2.7238 - val_loss: 3.0200 - val_seg_output_accuracy: 0.8704 - val_seg_output_loss: 0.3042
# Epoch 43/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - class_output_accuracy: 0.3450 - class_output_loss: 2.3351 - loss: 2.6477 - seg_output_accuracy: 0.8624 - seg_output_loss: 0.3127 - val_class_output_accuracy: 0.2280 - val_class_output_loss: 2.7045 - val_loss: 3.0007 - val_seg_output_accuracy: 0.8672 - val_seg_output_loss: 0.3041
# Epoch 44/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 254ms/step - class_output_accuracy: 0.3366 - class_output_loss: 2.3413 - loss: 2.6530 - seg_output_accuracy: 0.8624 - seg_output_loss: 0.3118 - val_class_output_accuracy: 0.2225 - val_class_output_loss: 2.6571 - val_loss: 2.9303 - val_seg_output_accuracy: 0.8688 - val_seg_output_loss: 0.3017
# Epoch 45/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 289ms/step - class_output_accuracy: 0.3295 - class_output_loss: 2.3297 - loss: 2.6387 - seg_output_accuracy: 0.8643 - seg_output_loss: 0.3090 - val_class_output_accuracy: 0.2389 - val_class_output_loss: 2.6584 - val_loss: 2.9126 - val_seg_output_accuracy: 0.8765 - val_seg_output_loss: 0.2896
# Epoch 46/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 289ms/step - class_output_accuracy: 0.3633 - class_output_loss: 2.2486 - loss: 2.5551 - seg_output_accuracy: 0.8656 - seg_output_loss: 0.3065 - val_class_output_accuracy: 0.2480 - val_class_output_loss: 2.5903 - val_loss: 2.8602 - val_seg_output_accuracy: 0.8791 - val_seg_output_loss: 0.2841
# Epoch 47/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - class_output_accuracy: 0.3673 - class_output_loss: 2.2255 - loss: 2.5288 - seg_output_accuracy: 0.8675 - seg_output_loss: 0.3033 - val_class_output_accuracy: 0.2679 - val_class_output_loss: 2.6256 - val_loss: 2.9013 - val_seg_output_accuracy: 0.8824 - val_seg_output_loss: 0.2764
# Epoch 48/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 291ms/step - class_output_accuracy: 0.3439 - class_output_loss: 2.2891 - loss: 2.5971 - seg_output_accuracy: 0.8646 - seg_output_loss: 0.3080 - val_class_output_accuracy: 0.2607 - val_class_output_loss: 2.5636 - val_loss: 2.8510 - val_seg_output_accuracy: 0.8790 - val_seg_output_loss: 0.2877
# Epoch 49/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 244ms/step - class_output_accuracy: 0.3645 - class_output_loss: 2.2024 - loss: 2.5041 - seg_output_accuracy: 0.8680 - seg_output_loss: 0.3015 - val_class_output_accuracy: 0.2670 - val_class_output_loss: 2.5462 - val_loss: 2.8210 - val_seg_output_accuracy: 0.8812 - val_seg_output_loss: 0.2777
# Epoch 50/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - class_output_accuracy: 0.3543 - class_output_loss: 2.2427 - loss: 2.5458 - seg_output_accuracy: 0.8675 - seg_output_loss: 0.3031 - val_class_output_accuracy: 0.2489 - val_class_output_loss: 2.6212 - val_loss: 2.9026 - val_seg_output_accuracy: 0.8756 - val_seg_output_loss: 0.2970
# Epoch 51/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 268ms/step - class_output_accuracy: 0.3823 - class_output_loss: 2.1394 - loss: 2.4414 - seg_output_accuracy: 0.8681 - seg_output_loss: 0.3020 - val_class_output_accuracy: 0.2062 - val_class_output_loss: 2.7640 - val_loss: 3.0155 - val_seg_output_accuracy: 0.8782 - val_seg_output_loss: 0.2845
# Epoch 52/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - class_output_accuracy: 0.3627 - class_output_loss: 2.1745 - loss: 2.4776 - seg_output_accuracy: 0.8671 - seg_output_loss: 0.3030 - val_class_output_accuracy: 0.2234 - val_class_output_loss: 2.7017 - val_loss: 2.9582 - val_seg_output_accuracy: 0.8773 - val_seg_output_loss: 0.2882
# Epoch 53/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - class_output_accuracy: 0.3843 - class_output_loss: 2.1335 - loss: 2.4352 - seg_output_accuracy: 0.8684 - seg_output_loss: 0.3017 - val_class_output_accuracy: 0.2952 - val_class_output_loss: 2.5147 - val_loss: 2.7746 - val_seg_output_accuracy: 0.8800 - val_seg_output_loss: 0.2829
# Epoch 54/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - class_output_accuracy: 0.3731 - class_output_loss: 2.1402 - loss: 2.4459 - seg_output_accuracy: 0.8665 - seg_output_loss: 0.3058 - val_class_output_accuracy: 0.3015 - val_class_output_loss: 2.3972 - val_loss: 2.6675 - val_seg_output_accuracy: 0.8817 - val_seg_output_loss: 0.2797
# Epoch 55/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 288ms/step - class_output_accuracy: 0.3772 - class_output_loss: 2.0917 - loss: 2.3883 - seg_output_accuracy: 0.8704 - seg_output_loss: 0.2966 - val_class_output_accuracy: 0.2625 - val_class_output_loss: 2.4772 - val_loss: 2.7306 - val_seg_output_accuracy: 0.8785 - val_seg_output_loss: 0.2836
# Epoch 56/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - class_output_accuracy: 0.3863 - class_output_loss: 2.1261 - loss: 2.4251 - seg_output_accuracy: 0.8697 - seg_output_loss: 0.2989 - val_class_output_accuracy: 0.2325 - val_class_output_loss: 2.6544 - val_loss: 2.9520 - val_seg_output_accuracy: 0.8618 - val_seg_output_loss: 0.3084
# Epoch 57/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 290ms/step - class_output_accuracy: 0.3922 - class_output_loss: 2.0772 - loss: 2.3720 - seg_output_accuracy: 0.8719 - seg_output_loss: 0.2948 - val_class_output_accuracy: 0.3006 - val_class_output_loss: 2.3957 - val_loss: 2.6644 - val_seg_output_accuracy: 0.8833 - val_seg_output_loss: 0.2789
# Epoch 58/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 289ms/step - class_output_accuracy: 0.4042 - class_output_loss: 2.0218 - loss: 2.3111 - seg_output_accuracy: 0.8737 - seg_output_loss: 0.2893 - val_class_output_accuracy: 0.2734 - val_class_output_loss: 2.5150 - val_loss: 2.7833 - val_seg_output_accuracy: 0.8763 - val_seg_output_loss: 0.2879
# Epoch 59/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 271ms/step - class_output_accuracy: 0.4216 - class_output_loss: 2.0150 - loss: 2.3113 - seg_output_accuracy: 0.8708 - seg_output_loss: 0.2963 - val_class_output_accuracy: 0.2906 - val_class_output_loss: 2.4552 - val_loss: 2.7236 - val_seg_output_accuracy: 0.8790 - val_seg_output_loss: 0.2842
# Epoch 60/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 291ms/step - class_output_accuracy: 0.4179 - class_output_loss: 2.0198 - loss: 2.3173 - seg_output_accuracy: 0.8695 - seg_output_loss: 0.2975 - val_class_output_accuracy: 0.2852 - val_class_output_loss: 2.4798 - val_loss: 2.7768 - val_seg_output_accuracy: 0.8669 - val_seg_output_loss: 0.2983
# Epoch 61/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - class_output_accuracy: 0.4193 - class_output_loss: 1.9786 - loss: 2.2739 - seg_output_accuracy: 0.8717 - seg_output_loss: 0.2952 - val_class_output_accuracy: 0.2716 - val_class_output_loss: 2.5244 - val_loss: 2.7683 - val_seg_output_accuracy: 0.8850 - val_seg_output_loss: 0.2758
# Epoch 62/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 288ms/step - class_output_accuracy: 0.4530 - class_output_loss: 1.9464 - loss: 2.2405 - seg_output_accuracy: 0.8714 - seg_output_loss: 0.2940 - val_class_output_accuracy: 0.2825 - val_class_output_loss: 2.5225 - val_loss: 2.7842 - val_seg_output_accuracy: 0.8805 - val_seg_output_loss: 0.2787
# Epoch 63/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 288ms/step - class_output_accuracy: 0.4151 - class_output_loss: 1.9926 - loss: 2.2803 - seg_output_accuracy: 0.8748 - seg_output_loss: 0.2877 - val_class_output_accuracy: 0.2879 - val_class_output_loss: 2.4060 - val_loss: 2.6728 - val_seg_output_accuracy: 0.8809 - val_seg_output_loss: 0.2785
# Epoch 64/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - class_output_accuracy: 0.4188 - class_output_loss: 1.9744 - loss: 2.2627 - seg_output_accuracy: 0.8741 - seg_output_loss: 0.2884 - val_class_output_accuracy: 0.2897 - val_class_output_loss: 2.4425 - val_loss: 2.6922 - val_seg_output_accuracy: 0.8843 - val_seg_output_loss: 0.2723
# Epoch 65/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 287ms/step - class_output_accuracy: 0.4564 - class_output_loss: 1.8838 - loss: 2.1720 - seg_output_accuracy: 0.8741 - seg_output_loss: 0.2881 - val_class_output_accuracy: 0.2879 - val_class_output_loss: 2.4931 - val_loss: 2.7538 - val_seg_output_accuracy: 0.8841 - val_seg_output_loss: 0.2711
# Epoch 66/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 272ms/step - class_output_accuracy: 0.4464 - class_output_loss: 1.8680 - loss: 2.1603 - seg_output_accuracy: 0.8718 - seg_output_loss: 0.2923 - val_class_output_accuracy: 0.2852 - val_class_output_loss: 2.5126 - val_loss: 2.7757 - val_seg_output_accuracy: 0.8834 - val_seg_output_loss: 0.2731
# Epoch 67/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 287ms/step - class_output_accuracy: 0.4502 - class_output_loss: 1.8983 - loss: 2.1842 - seg_output_accuracy: 0.8751 - seg_output_loss: 0.2858 - val_class_output_accuracy: 0.2834 - val_class_output_loss: 2.4051 - val_loss: 2.6530 - val_seg_output_accuracy: 0.8847 - val_seg_output_loss: 0.2703
# Epoch 68/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 229ms/step - class_output_accuracy: 0.4391 - class_output_loss: 1.9524 - loss: 2.2409 - seg_output_accuracy: 0.8734 - seg_output_loss: 0.2885 - val_class_output_accuracy: 0.3261 - val_class_output_loss: 2.3007 - val_loss: 2.5501 - val_seg_output_accuracy: 0.8859 - val_seg_output_loss: 0.2681
# Epoch 69/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - class_output_accuracy: 0.4640 - class_output_loss: 1.8521 - loss: 2.1366 - seg_output_accuracy: 0.8759 - seg_output_loss: 0.2847 - val_class_output_accuracy: 0.2943 - val_class_output_loss: 2.4048 - val_loss: 2.6716 - val_seg_output_accuracy: 0.8798 - val_seg_output_loss: 0.2817
# Epoch 70/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 226ms/step - class_output_accuracy: 0.4670 - class_output_loss: 1.8607 - loss: 2.1478 - seg_output_accuracy: 0.8744 - seg_output_loss: 0.2872 - val_class_output_accuracy: 0.3515 - val_class_output_loss: 2.2474 - val_loss: 2.4976 - val_seg_output_accuracy: 0.8870 - val_seg_output_loss: 0.2684
# Epoch 71/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - class_output_accuracy: 0.4787 - class_output_loss: 1.8163 - loss: 2.1014 - seg_output_accuracy: 0.8751 - seg_output_loss: 0.2852 - val_class_output_accuracy: 0.2834 - val_class_output_loss: 2.4631 - val_loss: 2.7157 - val_seg_output_accuracy: 0.8830 - val_seg_output_loss: 0.2746
# Epoch 72/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 254ms/step - class_output_accuracy: 0.4725 - class_output_loss: 1.7850 - loss: 2.0678 - seg_output_accuracy: 0.8766 - seg_output_loss: 0.2830 - val_class_output_accuracy: 0.3233 - val_class_output_loss: 2.2883 - val_loss: 2.5541 - val_seg_output_accuracy: 0.8804 - val_seg_output_loss: 0.2766
# Epoch 73/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - class_output_accuracy: 0.4606 - class_output_loss: 1.7986 - loss: 2.0829 - seg_output_accuracy: 0.8765 - seg_output_loss: 0.2843 - val_class_output_accuracy: 0.3306 - val_class_output_loss: 2.3087 - val_loss: 2.6278 - val_seg_output_accuracy: 0.8622 - val_seg_output_loss: 0.3212
# Epoch 74/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 286ms/step - class_output_accuracy: 0.4632 - class_output_loss: 1.8167 - loss: 2.1021 - seg_output_accuracy: 0.8750 - seg_output_loss: 0.2855 - val_class_output_accuracy: 0.3497 - val_class_output_loss: 2.2489 - val_loss: 2.5004 - val_seg_output_accuracy: 0.8839 - val_seg_output_loss: 0.2726
# Epoch 75/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - class_output_accuracy: 0.4764 - class_output_loss: 1.7284 - loss: 2.0069 - seg_output_accuracy: 0.8790 - seg_output_loss: 0.2785 - val_class_output_accuracy: 0.3261 - val_class_output_loss: 2.3153 - val_loss: 2.5688 - val_seg_output_accuracy: 0.8873 - val_seg_output_loss: 0.2649
# Epoch 76/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - class_output_accuracy: 0.4784 - class_output_loss: 1.7405 - loss: 2.0222 - seg_output_accuracy: 0.8768 - seg_output_loss: 0.2817 - val_class_output_accuracy: 0.3188 - val_class_output_loss: 2.2964 - val_loss: 2.5831 - val_seg_output_accuracy: 0.8737 - val_seg_output_loss: 0.2904
# Epoch 77/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 242ms/step - class_output_accuracy: 0.4727 - class_output_loss: 1.7726 - loss: 2.0552 - seg_output_accuracy: 0.8766 - seg_output_loss: 0.2826 - val_class_output_accuracy: 0.3297 - val_class_output_loss: 2.2559 - val_loss: 2.5142 - val_seg_output_accuracy: 0.8839 - val_seg_output_loss: 0.2702
# Epoch 78/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 253ms/step - class_output_accuracy: 0.5017 - class_output_loss: 1.7135 - loss: 1.9966 - seg_output_accuracy: 0.8773 - seg_output_loss: 0.2831 - val_class_output_accuracy: 0.3724 - val_class_output_loss: 2.2311 - val_loss: 2.4647 - val_seg_output_accuracy: 0.8892 - val_seg_output_loss: 0.2624
# Epoch 79/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 224ms/step - class_output_accuracy: 0.5077 - class_output_loss: 1.6918 - loss: 1.9729 - seg_output_accuracy: 0.8764 - seg_output_loss: 0.2812 - val_class_output_accuracy: 0.3297 - val_class_output_loss: 2.3320 - val_loss: 2.5665 - val_seg_output_accuracy: 0.8851 - val_seg_output_loss: 0.2690
# Epoch 80/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - class_output_accuracy: 0.5136 - class_output_loss: 1.6692 - loss: 1.9466 - seg_output_accuracy: 0.8791 - seg_output_loss: 0.2773 - val_class_output_accuracy: 0.3315 - val_class_output_loss: 2.2979 - val_loss: 2.5486 - val_seg_output_accuracy: 0.8876 - val_seg_output_loss: 0.2666
# Epoch 81/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - class_output_accuracy: 0.4908 - class_output_loss: 1.6868 - loss: 1.9714 - seg_output_accuracy: 0.8746 - seg_output_loss: 0.2847 - val_class_output_accuracy: 0.3179 - val_class_output_loss: 2.2967 - val_loss: 2.5516 - val_seg_output_accuracy: 0.8851 - val_seg_output_loss: 0.2693
# Epoch 82/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 285ms/step - class_output_accuracy: 0.5147 - class_output_loss: 1.6434 - loss: 1.9266 - seg_output_accuracy: 0.8759 - seg_output_loss: 0.2832 - val_class_output_accuracy: 0.3678 - val_class_output_loss: 2.1699 - val_loss: 2.4138 - val_seg_output_accuracy: 0.8886 - val_seg_output_loss: 0.2633
# Epoch 83/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - class_output_accuracy: 0.4989 - class_output_loss: 1.6396 - loss: 1.9164 - seg_output_accuracy: 0.8791 - seg_output_loss: 0.2768 - val_class_output_accuracy: 0.3370 - val_class_output_loss: 2.2664 - val_loss: 2.5410 - val_seg_output_accuracy: 0.8791 - val_seg_output_loss: 0.2812
# Epoch 84/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 241ms/step - class_output_accuracy: 0.5288 - class_output_loss: 1.6233 - loss: 1.9035 - seg_output_accuracy: 0.8777 - seg_output_loss: 0.2802 - val_class_output_accuracy: 0.3824 - val_class_output_loss: 2.0818 - val_loss: 2.3486 - val_seg_output_accuracy: 0.8832 - val_seg_output_loss: 0.2683
# Epoch 85/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - class_output_accuracy: 0.5274 - class_output_loss: 1.5728 - loss: 1.8453 - seg_output_accuracy: 0.8815 - seg_output_loss: 0.2724 - val_class_output_accuracy: 0.3215 - val_class_output_loss: 2.2278 - val_loss: 2.4896 - val_seg_output_accuracy: 0.8863 - val_seg_output_loss: 0.2648
# Epoch 86/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - class_output_accuracy: 0.5085 - class_output_loss: 1.6243 - loss: 1.9049 - seg_output_accuracy: 0.8774 - seg_output_loss: 0.2806 - val_class_output_accuracy: 0.3706 - val_class_output_loss: 2.1400 - val_loss: 2.3826 - val_seg_output_accuracy: 0.8844 - val_seg_output_loss: 0.2753
# Epoch 87/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 287ms/step - class_output_accuracy: 0.5240 - class_output_loss: 1.5818 - loss: 1.8572 - seg_output_accuracy: 0.8801 - seg_output_loss: 0.2753 - val_class_output_accuracy: 0.4015 - val_class_output_loss: 2.1194 - val_loss: 2.3792 - val_seg_output_accuracy: 0.8839 - val_seg_output_loss: 0.2693
# Epoch 88/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 244ms/step - class_output_accuracy: 0.5324 - class_output_loss: 1.5393 - loss: 1.8218 - seg_output_accuracy: 0.8764 - seg_output_loss: 0.2827 - val_class_output_accuracy: 0.3615 - val_class_output_loss: 2.1622 - val_loss: 2.4434 - val_seg_output_accuracy: 0.8753 - val_seg_output_loss: 0.2829
# Epoch 89/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.5535 - class_output_loss: 1.5308 - loss: 1.8097 - seg_output_accuracy: 0.8781 - seg_output_loss: 0.2788 - val_class_output_accuracy: 0.3878 - val_class_output_loss: 2.0753 - val_loss: 2.3541 - val_seg_output_accuracy: 0.8809 - val_seg_output_loss: 0.2760
# Epoch 90/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 284ms/step - class_output_accuracy: 0.5479 - class_output_loss: 1.5571 - loss: 1.8348 - seg_output_accuracy: 0.8790 - seg_output_loss: 0.2777 - val_class_output_accuracy: 0.3579 - val_class_output_loss: 2.2553 - val_loss: 2.4989 - val_seg_output_accuracy: 0.8871 - val_seg_output_loss: 0.2641
# Epoch 91/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 267ms/step - class_output_accuracy: 0.5270 - class_output_loss: 1.5315 - loss: 1.8090 - seg_output_accuracy: 0.8793 - seg_output_loss: 0.2776 - val_class_output_accuracy: 0.3778 - val_class_output_loss: 2.1161 - val_loss: 2.3823 - val_seg_output_accuracy: 0.8826 - val_seg_output_loss: 0.2739
# Epoch 92/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 286ms/step - class_output_accuracy: 0.5432 - class_output_loss: 1.5177 - loss: 1.7948 - seg_output_accuracy: 0.8794 - seg_output_loss: 0.2773 - val_class_output_accuracy: 0.3606 - val_class_output_loss: 2.2779 - val_loss: 2.5281 - val_seg_output_accuracy: 0.8852 - val_seg_output_loss: 0.2716
# Epoch 93/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 270ms/step - class_output_accuracy: 0.5546 - class_output_loss: 1.5091 - loss: 1.7846 - seg_output_accuracy: 0.8798 - seg_output_loss: 0.2756 - val_class_output_accuracy: 0.3787 - val_class_output_loss: 2.1677 - val_loss: 2.4202 - val_seg_output_accuracy: 0.8807 - val_seg_output_loss: 0.2793
# Epoch 94/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 288ms/step - class_output_accuracy: 0.5770 - class_output_loss: 1.4263 - loss: 1.7013 - seg_output_accuracy: 0.8796 - seg_output_loss: 0.2751 - val_class_output_accuracy: 0.3833 - val_class_output_loss: 2.0668 - val_loss: 2.3243 - val_seg_output_accuracy: 0.8874 - val_seg_output_loss: 0.2641
# training time exceeded and ending early
# training ended on epoch 94
# training time = 30.075013717015583 mins

# %%
#
# Fine-tuned MobileNet
#
# Pur your mobilenet model here. This will have the same structure as the from-scratch network above, but now the backbone will be mobilenet rather
# than something of your own design. The classification and segmentation heads will possibly be quite similar to what you have above. As per the
# from-scratch network, you may want to build this with just one output to start with, and then add the second when you get that working.

# build the rest of the model here

# train the model. As per the from-scratch model, you may wish to use the callback - though if the model is not trained until convergence you will
# need to explain the implications of this.

# 5. MobileNet
# Load MobileNetV3Small backbone
mobile_base = keras.applications.MobileNetV3Small(input_shape=(image_size, image_size, 3),
                                                  include_top=False,
                                                  include_preprocessing=False)

# Programmatically find layers for skip connections by checking output shapes
# We need layers with output shapes approximately (16, 16, channels) and (8, 8, channels) for image_size=128
input_tensor = Input(shape=(image_size, image_size, 3))
shape_dict = {}
for layer in mobile_base.layers:
    output = layer.output
    temp_model = Model(inputs=mobile_base.input, outputs=output)
    output_shape = temp_model.output_shape
    shape_dict[layer.name] = output_shape

# Find layers with spatial dimensions close to 16x16 and 8x8
layer_16x16 = None
layer_8x8 = None
for layer_name, shape in shape_dict.items():
    if len(shape) == 4:  # (batch, height, width, channels)
        height = shape[1]
        if height == 16 and layer_16x16 is None:
            layer_16x16 = layer_name
        if height == 8 and layer_8x8 is None:
            layer_8x8 = layer_name

# Print the selected layers and their shapes for verification
print(f"Selected layer for 16x16: {layer_16x16}, Shape: {shape_dict[layer_16x16]}")
print(f"Selected layer for 8x8: {layer_8x8}, Shape: {shape_dict[layer_8x8]}")

# Extract intermediate layers for skip connections
conv_16x16 = mobile_base.get_layer(layer_16x16).output
conv_8x8 = mobile_base.get_layer(layer_8x8).output

# Classification Head
class_head = GlobalAveragePooling2D()(mobile_base.output)  # (576,)
class_output = Dense(37, activation='softmax', name='class_output')(class_head)

# Segmentation Head (with Skip Connections)
seg_head = UpSampling2D((2, 2))(conv_8x8)  # (16, 16, channels)
seg_head = concatenate([seg_head, conv_16x16])  # Concatenate with 16x16 layer
seg_head = conv_block(seg_head, 64, spatial_dropout=0.2, max_pool=False)  # (16, 16, 64)
seg_head = UpSampling2D((2, 2))(seg_head)  # (32, 32, 64)
seg_head = conv_block(seg_head, 32, spatial_dropout=0.2, max_pool=False)  # (32, 32, 32)
seg_head = UpSampling2D((2, 2))(seg_head)  # (64, 64, 32)
seg_head = conv_block(seg_head, 16, spatial_dropout=0.2, max_pool=False)  # (64, 64, 16)
seg_head = UpSampling2D((2, 2))(seg_head)  # (128, 128, 16)
seg_output = Conv2D(1, (3, 3), padding='same', activation='sigmoid', name='seg_output')(seg_head)  # (128, 128, 1)

# Model
mobilenet_model = Model(inputs=mobile_base.input, outputs=[class_output, seg_output])

# Training: Stage 1 (Freeze backbone, train heads)
mobile_base.trainable = False
mobilenet_model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss=['sparse_categorical_crossentropy', 'binary_crossentropy'], loss_weights=[1.0, 1.0], metrics={'class_output': 'accuracy', 'seg_output': 'accuracy'})
mobilenet_model.fit(train_class_seg, epochs=10, verbose=True, validation_data=val_class_seg, callbacks=[TrainForTime(train_time)])

# Training: Stage 2 (Unfreeze last 3 blocks, fine-tune)
# Identify layers to unfreeze (e.g., last 3 blocks)
for layer in mobile_base.layers[-30:]:  # Approximate last 3 blocks
    layer.trainable = True
mobilenet_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss=['sparse_categorical_crossentropy', 'binary_crossentropy'], loss_weights=[1.0, 1.0], metrics={'class_output': 'accuracy', 'seg_output': 'accuracy'})
mobilenet_model.fit(train_class_seg, epochs=200, verbose=True, validation_data=val_class_seg, callbacks=[TrainForTime(train_time)])
# Out:
# Selected layer for 16x16: expanded_conv_1_depthwise, Shape: (None, 16, 16, 72)
# Selected layer for 8x8: expanded_conv_3_depthwise, Shape: (None, 8, 8, 96)
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 47s 458ms/step - class_output_accuracy: 0.1169 - class_output_loss: 3.4776 - loss: 3.9772 - seg_output_accuracy: 0.7513 - seg_output_loss: 0.4993 - val_class_output_accuracy: 0.3915 - val_class_output_loss: 2.2284 - val_loss: 2.6687 - val_seg_output_accuracy: 0.8142 - val_seg_output_loss: 0.4498
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - class_output_accuracy: 0.5283 - class_output_loss: 1.8332 - loss: 2.1894 - seg_output_accuracy: 0.8428 - seg_output_loss: 0.3562 - val_class_output_accuracy: 0.4995 - val_class_output_loss: 1.7324 - val_loss: 2.0617 - val_seg_output_accuracy: 0.8486 - val_seg_output_loss: 0.3399
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - class_output_accuracy: 0.6385 - class_output_loss: 1.3615 - loss: 1.6909 - seg_output_accuracy: 0.8553 - seg_output_loss: 0.3294 - val_class_output_accuracy: 0.5658 - val_class_output_loss: 1.5448 - val_loss: 1.9177 - val_seg_output_accuracy: 0.8362 - val_seg_output_loss: 0.3768
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - class_output_accuracy: 0.7032 - class_output_loss: 1.1159 - loss: 1.4324 - seg_output_accuracy: 0.8619 - seg_output_loss: 0.3165 - val_class_output_accuracy: 0.5695 - val_class_output_loss: 1.4520 - val_loss: 1.8011 - val_seg_output_accuracy: 0.8460 - val_seg_output_loss: 0.3502
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - class_output_accuracy: 0.7354 - class_output_loss: 0.9674 - loss: 1.2686 - seg_output_accuracy: 0.8696 - seg_output_loss: 0.3012 - val_class_output_accuracy: 0.6149 - val_class_output_loss: 1.3848 - val_loss: 1.7460 - val_seg_output_accuracy: 0.8296 - val_seg_output_loss: 0.3637
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 234ms/step - class_output_accuracy: 0.7699 - class_output_loss: 0.8798 - loss: 1.1738 - seg_output_accuracy: 0.8722 - seg_output_loss: 0.2940 - val_class_output_accuracy: 0.6004 - val_class_output_loss: 1.3450 - val_loss: 1.6496 - val_seg_output_accuracy: 0.8731 - val_seg_output_loss: 0.3061
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 209ms/step - class_output_accuracy: 0.7899 - class_output_loss: 0.7917 - loss: 1.0765 - seg_output_accuracy: 0.8768 - seg_output_loss: 0.2847 - val_class_output_accuracy: 0.6249 - val_class_output_loss: 1.3188 - val_loss: 1.7808 - val_seg_output_accuracy: 0.7803 - val_seg_output_loss: 0.4582
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 209ms/step - class_output_accuracy: 0.7991 - class_output_loss: 0.7359 - loss: 1.0142 - seg_output_accuracy: 0.8794 - seg_output_loss: 0.2783 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2999 - val_loss: 1.6066 - val_seg_output_accuracy: 0.8678 - val_seg_output_loss: 0.3053
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 208ms/step - class_output_accuracy: 0.8300 - class_output_loss: 0.6824 - loss: 0.9561 - seg_output_accuracy: 0.8820 - seg_output_loss: 0.2736 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2891 - val_loss: 1.6233 - val_seg_output_accuracy: 0.8523 - val_seg_output_loss: 0.3300
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 244ms/step - class_output_accuracy: 0.8343 - class_output_loss: 0.6462 - loss: 0.9186 - seg_output_accuracy: 0.8832 - seg_output_loss: 0.2724 - val_class_output_accuracy: 0.6203 - val_class_output_loss: 1.2842 - val_loss: 1.6781 - val_seg_output_accuracy: 0.8338 - val_seg_output_loss: 0.3880
# Epoch 1/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 53s 484ms/step - class_output_accuracy: 0.6379 - class_output_loss: 1.2077 - loss: 1.4750 - seg_output_accuracy: 0.8850 - seg_output_loss: 0.2673 - val_class_output_accuracy: 0.6285 - val_class_output_loss: 1.2625 - val_loss: 1.5316 - val_seg_output_accuracy: 0.8853 - val_seg_output_loss: 0.2646
# Epoch 2/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 213ms/step - class_output_accuracy: 0.6676 - class_output_loss: 1.1285 - loss: 1.3922 - seg_output_accuracy: 0.8862 - seg_output_loss: 0.2637 - val_class_output_accuracy: 0.6276 - val_class_output_loss: 1.2525 - val_loss: 1.5098 - val_seg_output_accuracy: 0.8911 - val_seg_output_loss: 0.2527
# Epoch 3/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 206ms/step - class_output_accuracy: 0.7108 - class_output_loss: 1.0272 - loss: 1.2867 - seg_output_accuracy: 0.8880 - seg_output_loss: 0.2594 - val_class_output_accuracy: 0.6267 - val_class_output_loss: 1.2479 - val_loss: 1.5042 - val_seg_output_accuracy: 0.8923 - val_seg_output_loss: 0.2510
# Epoch 4/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 209ms/step - class_output_accuracy: 0.7265 - class_output_loss: 0.9559 - loss: 1.2169 - seg_output_accuracy: 0.8880 - seg_output_loss: 0.2611 - val_class_output_accuracy: 0.6249 - val_class_output_loss: 1.2466 - val_loss: 1.5029 - val_seg_output_accuracy: 0.8929 - val_seg_output_loss: 0.2506
# Epoch 5/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 256ms/step - class_output_accuracy: 0.7465 - class_output_loss: 0.9054 - loss: 1.1650 - seg_output_accuracy: 0.8884 - seg_output_loss: 0.2597 - val_class_output_accuracy: 0.6267 - val_class_output_loss: 1.2480 - val_loss: 1.5043 - val_seg_output_accuracy: 0.8933 - val_seg_output_loss: 0.2496
# Epoch 6/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 210ms/step - class_output_accuracy: 0.7533 - class_output_loss: 0.8561 - loss: 1.1143 - seg_output_accuracy: 0.8896 - seg_output_loss: 0.2582 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2501 - val_loss: 1.5065 - val_seg_output_accuracy: 0.8937 - val_seg_output_loss: 0.2494
# Epoch 7/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - class_output_accuracy: 0.7541 - class_output_loss: 0.8666 - loss: 1.1246 - seg_output_accuracy: 0.8891 - seg_output_loss: 0.2580 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2531 - val_loss: 1.5094 - val_seg_output_accuracy: 0.8939 - val_seg_output_loss: 0.2489
# Epoch 8/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 211ms/step - class_output_accuracy: 0.7734 - class_output_loss: 0.7949 - loss: 1.0532 - seg_output_accuracy: 0.8882 - seg_output_loss: 0.2583 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2548 - val_loss: 1.5114 - val_seg_output_accuracy: 0.8939 - val_seg_output_loss: 0.2485
# Epoch 9/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - class_output_accuracy: 0.7755 - class_output_loss: 0.7709 - loss: 1.0255 - seg_output_accuracy: 0.8897 - seg_output_loss: 0.2546 - val_class_output_accuracy: 0.6222 - val_class_output_loss: 1.2568 - val_loss: 1.5138 - val_seg_output_accuracy: 0.8938 - val_seg_output_loss: 0.2484
# Epoch 10/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - class_output_accuracy: 0.7948 - class_output_loss: 0.7294 - loss: 0.9840 - seg_output_accuracy: 0.8904 - seg_output_loss: 0.2546 - val_class_output_accuracy: 0.6231 - val_class_output_loss: 1.2592 - val_loss: 1.5164 - val_seg_output_accuracy: 0.8940 - val_seg_output_loss: 0.2486
# Epoch 11/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 211ms/step - class_output_accuracy: 0.7901 - class_output_loss: 0.7149 - loss: 0.9731 - seg_output_accuracy: 0.8889 - seg_output_loss: 0.2583 - val_class_output_accuracy: 0.6213 - val_class_output_loss: 1.2602 - val_loss: 1.5175 - val_seg_output_accuracy: 0.8942 - val_seg_output_loss: 0.2482
# Epoch 12/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 238ms/step - class_output_accuracy: 0.8034 - class_output_loss: 0.6960 - loss: 0.9499 - seg_output_accuracy: 0.8906 - seg_output_loss: 0.2540 - val_class_output_accuracy: 0.6213 - val_class_output_loss: 1.2619 - val_loss: 1.5194 - val_seg_output_accuracy: 0.8941 - val_seg_output_loss: 0.2478
# Epoch 13/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 256ms/step - class_output_accuracy: 0.7980 - class_output_loss: 0.6837 - loss: 0.9357 - seg_output_accuracy: 0.8915 - seg_output_loss: 0.2521 - val_class_output_accuracy: 0.6222 - val_class_output_loss: 1.2631 - val_loss: 1.5205 - val_seg_output_accuracy: 0.8942 - val_seg_output_loss: 0.2475
# Epoch 14/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 257ms/step - class_output_accuracy: 0.8001 - class_output_loss: 0.6800 - loss: 0.9362 - seg_output_accuracy: 0.8901 - seg_output_loss: 0.2562 - val_class_output_accuracy: 0.6213 - val_class_output_loss: 1.2639 - val_loss: 1.5216 - val_seg_output_accuracy: 0.8942 - val_seg_output_loss: 0.2477
# Epoch 15/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - class_output_accuracy: 0.8091 - class_output_loss: 0.6535 - loss: 0.9122 - seg_output_accuracy: 0.8884 - seg_output_loss: 0.2589 - val_class_output_accuracy: 0.6222 - val_class_output_loss: 1.2648 - val_loss: 1.5222 - val_seg_output_accuracy: 0.8945 - val_seg_output_loss: 0.2472
# Epoch 16/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 258ms/step - class_output_accuracy: 0.8216 - class_output_loss: 0.6345 - loss: 0.8929 - seg_output_accuracy: 0.8892 - seg_output_loss: 0.2583 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2659 - val_loss: 1.5234 - val_seg_output_accuracy: 0.8946 - val_seg_output_loss: 0.2470
# Epoch 17/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 243ms/step - class_output_accuracy: 0.8113 - class_output_loss: 0.6478 - loss: 0.9009 - seg_output_accuracy: 0.8914 - seg_output_loss: 0.2531 - val_class_output_accuracy: 0.6249 - val_class_output_loss: 1.2662 - val_loss: 1.5235 - val_seg_output_accuracy: 0.8947 - val_seg_output_loss: 0.2468
# Epoch 18/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - class_output_accuracy: 0.8335 - class_output_loss: 0.5815 - loss: 0.8361 - seg_output_accuracy: 0.8903 - seg_output_loss: 0.2547 - val_class_output_accuracy: 0.6249 - val_class_output_loss: 1.2677 - val_loss: 1.5255 - val_seg_output_accuracy: 0.8946 - val_seg_output_loss: 0.2469
# Epoch 19/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - class_output_accuracy: 0.8355 - class_output_loss: 0.5784 - loss: 0.8334 - seg_output_accuracy: 0.8902 - seg_output_loss: 0.2550 - val_class_output_accuracy: 0.6231 - val_class_output_loss: 1.2690 - val_loss: 1.5267 - val_seg_output_accuracy: 0.8947 - val_seg_output_loss: 0.2464
# Epoch 20/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - class_output_accuracy: 0.8340 - class_output_loss: 0.5757 - loss: 0.8284 - seg_output_accuracy: 0.8918 - seg_output_loss: 0.2527 - val_class_output_accuracy: 0.6240 - val_class_output_loss: 1.2698 - val_loss: 1.5274 - val_seg_output_accuracy: 0.8950 - val_seg_output_loss: 0.2462
# Epoch 21/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 216ms/step - class_output_accuracy: 0.8465 - class_output_loss: 0.5574 - loss: 0.8113 - seg_output_accuracy: 0.8911 - seg_output_loss: 0.2540 - val_class_output_accuracy: 0.6222 - val_class_output_loss: 1.2715 - val_loss: 1.5291 - val_seg_output_accuracy: 0.8951 - val_seg_output_loss: 0.2460
# Epoch 22/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 258ms/step - class_output_accuracy: 0.8400 - class_output_loss: 0.5751 - loss: 0.8277 - seg_output_accuracy: 0.8920 - seg_output_loss: 0.2526 - val_class_output_accuracy: 0.6194 - val_class_output_loss: 1.2727 - val_loss: 1.5303 - val_seg_output_accuracy: 0.8950 - val_seg_output_loss: 0.2460
# Epoch 23/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 259ms/step - class_output_accuracy: 0.8356 - class_output_loss: 0.5552 - loss: 0.8096 - seg_output_accuracy: 0.8906 - seg_output_loss: 0.2544 - val_class_output_accuracy: 0.6194 - val_class_output_loss: 1.2746 - val_loss: 1.5321 - val_seg_output_accuracy: 0.8951 - val_seg_output_loss: 0.2459
# Epoch 24/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - class_output_accuracy: 0.8554 - class_output_loss: 0.5336 - loss: 0.7891 - seg_output_accuracy: 0.8900 - seg_output_loss: 0.2554 - val_class_output_accuracy: 0.6176 - val_class_output_loss: 1.2760 - val_loss: 1.5333 - val_seg_output_accuracy: 0.8953 - val_seg_output_loss: 0.2459
# Epoch 25/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - class_output_accuracy: 0.8438 - class_output_loss: 0.5287 - loss: 0.7856 - seg_output_accuracy: 0.8896 - seg_output_loss: 0.2569 - val_class_output_accuracy: 0.6176 - val_class_output_loss: 1.2778 - val_loss: 1.5353 - val_seg_output_accuracy: 0.8952 - val_seg_output_loss: 0.2457
# Epoch 26/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 215ms/step - class_output_accuracy: 0.8437 - class_output_loss: 0.5331 - loss: 0.7861 - seg_output_accuracy: 0.8907 - seg_output_loss: 0.2531 - val_class_output_accuracy: 0.6176 - val_class_output_loss: 1.2796 - val_loss: 1.5373 - val_seg_output_accuracy: 0.8950 - val_seg_output_loss: 0.2455
# Epoch 27/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 248ms/step - class_output_accuracy: 0.8521 - class_output_loss: 0.5151 - loss: 0.7670 - seg_output_accuracy: 0.8914 - seg_output_loss: 0.2518 - val_class_output_accuracy: 0.6185 - val_class_output_loss: 1.2821 - val_loss: 1.5397 - val_seg_output_accuracy: 0.8952 - val_seg_output_loss: 0.2456
# Epoch 28/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 257ms/step - class_output_accuracy: 0.8638 - class_output_loss: 0.4999 - loss: 0.7523 - seg_output_accuracy: 0.8910 - seg_output_loss: 0.2525 - val_class_output_accuracy: 0.6194 - val_class_output_loss: 1.2841 - val_loss: 1.5415 - val_seg_output_accuracy: 0.8954 - val_seg_output_loss: 0.2457
# Epoch 29/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 214ms/step - class_output_accuracy: 0.8715 - class_output_loss: 0.4809 - loss: 0.7391 - seg_output_accuracy: 0.8894 - seg_output_loss: 0.2581 - val_class_output_accuracy: 0.6185 - val_class_output_loss: 1.2864 - val_loss: 1.5438 - val_seg_output_accuracy: 0.8953 - val_seg_output_loss: 0.2455
# Epoch 30/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - class_output_accuracy: 0.8638 - class_output_loss: 0.4844 - loss: 0.7351 - seg_output_accuracy: 0.8920 - seg_output_loss: 0.2508 - val_class_output_accuracy: 0.6203 - val_class_output_loss: 1.2889 - val_loss: 1.5458 - val_seg_output_accuracy: 0.8955 - val_seg_output_loss: 0.2452
# Epoch 31/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - class_output_accuracy: 0.8654 - class_output_loss: 0.4702 - loss: 0.7253 - seg_output_accuracy: 0.8902 - seg_output_loss: 0.2551 - val_class_output_accuracy: 0.6203 - val_class_output_loss: 1.2909 - val_loss: 1.5477 - val_seg_output_accuracy: 0.8957 - val_seg_output_loss: 0.2450
# Epoch 32/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - class_output_accuracy: 0.8609 - class_output_loss: 0.4840 - loss: 0.7391 - seg_output_accuracy: 0.8901 - seg_output_loss: 0.2551 - val_class_output_accuracy: 0.6194 - val_class_output_loss: 1.2931 - val_loss: 1.5499 - val_seg_output_accuracy: 0.8956 - val_seg_output_loss: 0.2452
# Epoch 33/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 214ms/step - class_output_accuracy: 0.8731 - class_output_loss: 0.4652 - loss: 0.7204 - seg_output_accuracy: 0.8904 - seg_output_loss: 0.2553 - val_class_output_accuracy: 0.6167 - val_class_output_loss: 1.2959 - val_loss: 1.5528 - val_seg_output_accuracy: 0.8953 - val_seg_output_loss: 0.2450
# Epoch 34/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 212ms/step - class_output_accuracy: 0.8712 - class_output_loss: 0.4596 - loss: 0.7144 - seg_output_accuracy: 0.8904 - seg_output_loss: 0.2547 - val_class_output_accuracy: 0.6158 - val_class_output_loss: 1.2978 - val_loss: 1.5543 - val_seg_output_accuracy: 0.8954 - val_seg_output_loss: 0.2448
# Epoch 35/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.8758 - class_output_loss: 0.4475 - loss: 0.7006 - seg_output_accuracy: 0.8909 - seg_output_loss: 0.2532 - val_class_output_accuracy: 0.6158 - val_class_output_loss: 1.3000 - val_loss: 1.5565 - val_seg_output_accuracy: 0.8956 - val_seg_output_loss: 0.2453
# Epoch 36/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 256ms/step - class_output_accuracy: 0.8774 - class_output_loss: 0.4519 - loss: 0.7078 - seg_output_accuracy: 0.8902 - seg_output_loss: 0.2558 - val_class_output_accuracy: 0.6149 - val_class_output_loss: 1.3025 - val_loss: 1.5586 - val_seg_output_accuracy: 0.8956 - val_seg_output_loss: 0.2447
# Epoch 37/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.8759 - class_output_loss: 0.4440 - loss: 0.6919 - seg_output_accuracy: 0.8930 - seg_output_loss: 0.2479 - val_class_output_accuracy: 0.6131 - val_class_output_loss: 1.3052 - val_loss: 1.5612 - val_seg_output_accuracy: 0.8957 - val_seg_output_loss: 0.2450
# Epoch 38/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 238ms/step - class_output_accuracy: 0.8852 - class_output_loss: 0.4247 - loss: 0.6795 - seg_output_accuracy: 0.8895 - seg_output_loss: 0.2548 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3072 - val_loss: 1.5631 - val_seg_output_accuracy: 0.8956 - val_seg_output_loss: 0.2449
# Epoch 39/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 258ms/step - class_output_accuracy: 0.8823 - class_output_loss: 0.4336 - loss: 0.6838 - seg_output_accuracy: 0.8920 - seg_output_loss: 0.2502 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3092 - val_loss: 1.5650 - val_seg_output_accuracy: 0.8956 - val_seg_output_loss: 0.2446
# Epoch 40/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - class_output_accuracy: 0.8891 - class_output_loss: 0.4159 - loss: 0.6670 - seg_output_accuracy: 0.8917 - seg_output_loss: 0.2511 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3110 - val_loss: 1.5665 - val_seg_output_accuracy: 0.8958 - val_seg_output_loss: 0.2444
# Epoch 41/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - class_output_accuracy: 0.8934 - class_output_loss: 0.4118 - loss: 0.6637 - seg_output_accuracy: 0.8919 - seg_output_loss: 0.2520 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3124 - val_loss: 1.5678 - val_seg_output_accuracy: 0.8959 - val_seg_output_loss: 0.2442
# Epoch 42/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 215ms/step - class_output_accuracy: 0.9040 - class_output_loss: 0.3945 - loss: 0.6454 - seg_output_accuracy: 0.8910 - seg_output_loss: 0.2508 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3143 - val_loss: 1.5697 - val_seg_output_accuracy: 0.8960 - val_seg_output_loss: 0.2441
# Epoch 43/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 237ms/step - class_output_accuracy: 0.8933 - class_output_loss: 0.3904 - loss: 0.6401 - seg_output_accuracy: 0.8924 - seg_output_loss: 0.2497 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3165 - val_loss: 1.5724 - val_seg_output_accuracy: 0.8959 - val_seg_output_loss: 0.2446
# Epoch 44/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 217ms/step - class_output_accuracy: 0.9023 - class_output_loss: 0.3771 - loss: 0.6280 - seg_output_accuracy: 0.8926 - seg_output_loss: 0.2510 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3199 - val_loss: 1.5759 - val_seg_output_accuracy: 0.8957 - val_seg_output_loss: 0.2443
# Epoch 45/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - class_output_accuracy: 0.8933 - class_output_loss: 0.3912 - loss: 0.6432 - seg_output_accuracy: 0.8917 - seg_output_loss: 0.2519 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3220 - val_loss: 1.5774 - val_seg_output_accuracy: 0.8959 - val_seg_output_loss: 0.2440
# Epoch 46/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - class_output_accuracy: 0.9148 - class_output_loss: 0.3735 - loss: 0.6275 - seg_output_accuracy: 0.8910 - seg_output_loss: 0.2540 - val_class_output_accuracy: 0.6131 - val_class_output_loss: 1.3249 - val_loss: 1.5804 - val_seg_output_accuracy: 0.8960 - val_seg_output_loss: 0.2442
# Epoch 47/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 240ms/step - class_output_accuracy: 0.9060 - class_output_loss: 0.3681 - loss: 0.6181 - seg_output_accuracy: 0.8919 - seg_output_loss: 0.2500 - val_class_output_accuracy: 0.6149 - val_class_output_loss: 1.3273 - val_loss: 1.5825 - val_seg_output_accuracy: 0.8960 - val_seg_output_loss: 0.2440
# Epoch 48/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 216ms/step - class_output_accuracy: 0.9082 - class_output_loss: 0.3631 - loss: 0.6187 - seg_output_accuracy: 0.8905 - seg_output_loss: 0.2557 - val_class_output_accuracy: 0.6140 - val_class_output_loss: 1.3298 - val_loss: 1.5849 - val_seg_output_accuracy: 0.8961 - val_seg_output_loss: 0.2439
# Epoch 49/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 256ms/step - class_output_accuracy: 0.9148 - class_output_loss: 0.3512 - loss: 0.6015 - seg_output_accuracy: 0.8922 - seg_output_loss: 0.2504 - val_class_output_accuracy: 0.6140 - val_class_output_loss: 1.3324 - val_loss: 1.5868 - val_seg_output_accuracy: 0.8963 - val_seg_output_loss: 0.2436
# Epoch 50/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 258ms/step - class_output_accuracy: 0.9147 - class_output_loss: 0.3709 - loss: 0.6239 - seg_output_accuracy: 0.8911 - seg_output_loss: 0.2530 - val_class_output_accuracy: 0.6131 - val_class_output_loss: 1.3346 - val_loss: 1.5892 - val_seg_output_accuracy: 0.8961 - val_seg_output_loss: 0.2437
# Epoch 51/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 217ms/step - class_output_accuracy: 0.9085 - class_output_loss: 0.3703 - loss: 0.6230 - seg_output_accuracy: 0.8910 - seg_output_loss: 0.2527 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3374 - val_loss: 1.5917 - val_seg_output_accuracy: 0.8962 - val_seg_output_loss: 0.2438
# Epoch 52/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - class_output_accuracy: 0.9171 - class_output_loss: 0.3433 - loss: 0.5942 - seg_output_accuracy: 0.8921 - seg_output_loss: 0.2511 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3371 - val_loss: 1.5915 - val_seg_output_accuracy: 0.8962 - val_seg_output_loss: 0.2439
# Epoch 53/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 257ms/step - class_output_accuracy: 0.9179 - class_output_loss: 0.3388 - loss: 0.5899 - seg_output_accuracy: 0.8921 - seg_output_loss: 0.2512 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3392 - val_loss: 1.5935 - val_seg_output_accuracy: 0.8963 - val_seg_output_loss: 0.2440
# Epoch 54/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.9274 - class_output_loss: 0.3330 - loss: 0.5847 - seg_output_accuracy: 0.8912 - seg_output_loss: 0.2517 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3409 - val_loss: 1.5945 - val_seg_output_accuracy: 0.8962 - val_seg_output_loss: 0.2434
# Epoch 55/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 243ms/step - class_output_accuracy: 0.9244 - class_output_loss: 0.3410 - loss: 0.5914 - seg_output_accuracy: 0.8922 - seg_output_loss: 0.2504 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3440 - val_loss: 1.5977 - val_seg_output_accuracy: 0.8961 - val_seg_output_loss: 0.2434
# Epoch 56/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - class_output_accuracy: 0.9278 - class_output_loss: 0.3201 - loss: 0.5722 - seg_output_accuracy: 0.8923 - seg_output_loss: 0.2521 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3467 - val_loss: 1.6004 - val_seg_output_accuracy: 0.8961 - val_seg_output_loss: 0.2433
# Epoch 57/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 257ms/step - class_output_accuracy: 0.9288 - class_output_loss: 0.3223 - loss: 0.5685 - seg_output_accuracy: 0.8938 - seg_output_loss: 0.2463 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3488 - val_loss: 1.6025 - val_seg_output_accuracy: 0.8962 - val_seg_output_loss: 0.2436
# Epoch 58/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 258ms/step - class_output_accuracy: 0.9289 - class_output_loss: 0.3264 - loss: 0.5766 - seg_output_accuracy: 0.8928 - seg_output_loss: 0.2502 - val_class_output_accuracy: 0.6067 - val_class_output_loss: 1.3510 - val_loss: 1.6042 - val_seg_output_accuracy: 0.8963 - val_seg_output_loss: 0.2432
# Epoch 59/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - class_output_accuracy: 0.9342 - class_output_loss: 0.3050 - loss: 0.5558 - seg_output_accuracy: 0.8922 - seg_output_loss: 0.2508 - val_class_output_accuracy: 0.6076 - val_class_output_loss: 1.3543 - val_loss: 1.6077 - val_seg_output_accuracy: 0.8964 - val_seg_output_loss: 0.2437
# Epoch 60/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 260ms/step - class_output_accuracy: 0.9216 - class_output_loss: 0.3245 - loss: 0.5776 - seg_output_accuracy: 0.8912 - seg_output_loss: 0.2531 - val_class_output_accuracy: 0.6067 - val_class_output_loss: 1.3563 - val_loss: 1.6093 - val_seg_output_accuracy: 0.8963 - val_seg_output_loss: 0.2429
# Epoch 61/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 241ms/step - class_output_accuracy: 0.9326 - class_output_loss: 0.3063 - loss: 0.5546 - seg_output_accuracy: 0.8928 - seg_output_loss: 0.2484 - val_class_output_accuracy: 0.6067 - val_class_output_loss: 1.3586 - val_loss: 1.6118 - val_seg_output_accuracy: 0.8962 - val_seg_output_loss: 0.2430
# Epoch 62/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - class_output_accuracy: 0.9268 - class_output_loss: 0.3058 - loss: 0.5565 - seg_output_accuracy: 0.8917 - seg_output_loss: 0.2507 - val_class_output_accuracy: 0.6067 - val_class_output_loss: 1.3605 - val_loss: 1.6134 - val_seg_output_accuracy: 0.8966 - val_seg_output_loss: 0.2431
# Epoch 63/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 210ms/step - class_output_accuracy: 0.9330 - class_output_loss: 0.3006 - loss: 0.5504 - seg_output_accuracy: 0.8919 - seg_output_loss: 0.2498 - val_class_output_accuracy: 0.6058 - val_class_output_loss: 1.3629 - val_loss: 1.6154 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2425
# Epoch 64/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 218ms/step - class_output_accuracy: 0.9389 - class_output_loss: 0.2985 - loss: 0.5475 - seg_output_accuracy: 0.8931 - seg_output_loss: 0.2489 - val_class_output_accuracy: 0.6058 - val_class_output_loss: 1.3648 - val_loss: 1.6176 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2431
# Epoch 65/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 214ms/step - class_output_accuracy: 0.9450 - class_output_loss: 0.2824 - loss: 0.5315 - seg_output_accuracy: 0.8928 - seg_output_loss: 0.2491 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3664 - val_loss: 1.6190 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2429
# Epoch 66/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 201ms/step - class_output_accuracy: 0.9441 - class_output_loss: 0.2801 - loss: 0.5295 - seg_output_accuracy: 0.8923 - seg_output_loss: 0.2495 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3682 - val_loss: 1.6207 - val_seg_output_accuracy: 0.8965 - val_seg_output_loss: 0.2427
# Epoch 67/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - class_output_accuracy: 0.9453 - class_output_loss: 0.2749 - loss: 0.5270 - seg_output_accuracy: 0.8915 - seg_output_loss: 0.2522 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3706 - val_loss: 1.6229 - val_seg_output_accuracy: 0.8964 - val_seg_output_loss: 0.2426
# Epoch 68/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 257ms/step - class_output_accuracy: 0.9504 - class_output_loss: 0.2744 - loss: 0.5226 - seg_output_accuracy: 0.8926 - seg_output_loss: 0.2481 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3727 - val_loss: 1.6245 - val_seg_output_accuracy: 0.8966 - val_seg_output_loss: 0.2423
# Epoch 69/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 238ms/step - class_output_accuracy: 0.9375 - class_output_loss: 0.2851 - loss: 0.5310 - seg_output_accuracy: 0.8942 - seg_output_loss: 0.2460 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3738 - val_loss: 1.6257 - val_seg_output_accuracy: 0.8966 - val_seg_output_loss: 0.2426
# Epoch 70/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - class_output_accuracy: 0.9479 - class_output_loss: 0.2666 - loss: 0.5150 - seg_output_accuracy: 0.8929 - seg_output_loss: 0.2484 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3761 - val_loss: 1.6282 - val_seg_output_accuracy: 0.8966 - val_seg_output_loss: 0.2428
# Epoch 71/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - class_output_accuracy: 0.9450 - class_output_loss: 0.2687 - loss: 0.5136 - seg_output_accuracy: 0.8943 - seg_output_loss: 0.2449 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3785 - val_loss: 1.6306 - val_seg_output_accuracy: 0.8966 - val_seg_output_loss: 0.2429
# Epoch 72/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 257ms/step - class_output_accuracy: 0.9545 - class_output_loss: 0.2493 - loss: 0.4997 - seg_output_accuracy: 0.8925 - seg_output_loss: 0.2504 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3789 - val_loss: 1.6307 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2425
# Epoch 73/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 248ms/step - class_output_accuracy: 0.9500 - class_output_loss: 0.2603 - loss: 0.5095 - seg_output_accuracy: 0.8927 - seg_output_loss: 0.2492 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3811 - val_loss: 1.6327 - val_seg_output_accuracy: 0.8968 - val_seg_output_loss: 0.2423
# Epoch 74/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 216ms/step - class_output_accuracy: 0.9545 - class_output_loss: 0.2632 - loss: 0.5123 - seg_output_accuracy: 0.8924 - seg_output_loss: 0.2492 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3822 - val_loss: 1.6335 - val_seg_output_accuracy: 0.8970 - val_seg_output_loss: 0.2425
# Epoch 75/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 212ms/step - class_output_accuracy: 0.9549 - class_output_loss: 0.2507 - loss: 0.4990 - seg_output_accuracy: 0.8936 - seg_output_loss: 0.2484 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3853 - val_loss: 1.6365 - val_seg_output_accuracy: 0.8969 - val_seg_output_loss: 0.2420
# Epoch 76/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 258ms/step - class_output_accuracy: 0.9591 - class_output_loss: 0.2448 - loss: 0.4907 - seg_output_accuracy: 0.8942 - seg_output_loss: 0.2459 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3865 - val_loss: 1.6378 - val_seg_output_accuracy: 0.8969 - val_seg_output_loss: 0.2426
# Epoch 77/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 236ms/step - class_output_accuracy: 0.9443 - class_output_loss: 0.2589 - loss: 0.5093 - seg_output_accuracy: 0.8922 - seg_output_loss: 0.2505 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3872 - val_loss: 1.6385 - val_seg_output_accuracy: 0.8968 - val_seg_output_loss: 0.2426
# Epoch 78/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 258ms/step - class_output_accuracy: 0.9595 - class_output_loss: 0.2382 - loss: 0.4887 - seg_output_accuracy: 0.8921 - seg_output_loss: 0.2505 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3877 - val_loss: 1.6386 - val_seg_output_accuracy: 0.8969 - val_seg_output_loss: 0.2420
# Epoch 79/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - class_output_accuracy: 0.9635 - class_output_loss: 0.2308 - loss: 0.4797 - seg_output_accuracy: 0.8923 - seg_output_loss: 0.2489 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3875 - val_loss: 1.6384 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2418
# Epoch 80/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - class_output_accuracy: 0.9588 - class_output_loss: 0.2348 - loss: 0.4854 - seg_output_accuracy: 0.8919 - seg_output_loss: 0.2507 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.3886 - val_loss: 1.6394 - val_seg_output_accuracy: 0.8968 - val_seg_output_loss: 0.2421
# Epoch 81/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 219ms/step - class_output_accuracy: 0.9648 - class_output_loss: 0.2245 - loss: 0.4700 - seg_output_accuracy: 0.8937 - seg_output_loss: 0.2456 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3890 - val_loss: 1.6402 - val_seg_output_accuracy: 0.8967 - val_seg_output_loss: 0.2421
# Epoch 82/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 214ms/step - class_output_accuracy: 0.9618 - class_output_loss: 0.2294 - loss: 0.4765 - seg_output_accuracy: 0.8938 - seg_output_loss: 0.2471 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3902 - val_loss: 1.6410 - val_seg_output_accuracy: 0.8970 - val_seg_output_loss: 0.2419
# Epoch 83/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 216ms/step - class_output_accuracy: 0.9674 - class_output_loss: 0.2260 - loss: 0.4766 - seg_output_accuracy: 0.8927 - seg_output_loss: 0.2507 - val_class_output_accuracy: 0.6085 - val_class_output_loss: 1.3923 - val_loss: 1.6431 - val_seg_output_accuracy: 0.8970 - val_seg_output_loss: 0.2417
# Epoch 84/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 215ms/step - class_output_accuracy: 0.9689 - class_output_loss: 0.2196 - loss: 0.4698 - seg_output_accuracy: 0.8922 - seg_output_loss: 0.2502 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3942 - val_loss: 1.6448 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2418
# Epoch 85/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - class_output_accuracy: 0.9658 - class_output_loss: 0.2144 - loss: 0.4617 - seg_output_accuracy: 0.8938 - seg_output_loss: 0.2473 - val_class_output_accuracy: 0.6131 - val_class_output_loss: 1.3965 - val_loss: 1.6473 - val_seg_output_accuracy: 0.8970 - val_seg_output_loss: 0.2423
# Epoch 86/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - class_output_accuracy: 0.9708 - class_output_loss: 0.2133 - loss: 0.4634 - seg_output_accuracy: 0.8930 - seg_output_loss: 0.2501 - val_class_output_accuracy: 0.6113 - val_class_output_loss: 1.3986 - val_loss: 1.6490 - val_seg_output_accuracy: 0.8970 - val_seg_output_loss: 0.2418
# Epoch 87/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 216ms/step - class_output_accuracy: 0.9649 - class_output_loss: 0.2142 - loss: 0.4612 - seg_output_accuracy: 0.8936 - seg_output_loss: 0.2470 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.3994 - val_loss: 1.6498 - val_seg_output_accuracy: 0.8971 - val_seg_output_loss: 0.2414
# Epoch 88/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 243ms/step - class_output_accuracy: 0.9698 - class_output_loss: 0.2087 - loss: 0.4572 - seg_output_accuracy: 0.8933 - seg_output_loss: 0.2485 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.3999 - val_loss: 1.6501 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2413
# Epoch 89/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 260ms/step - class_output_accuracy: 0.9670 - class_output_loss: 0.2151 - loss: 0.4650 - seg_output_accuracy: 0.8919 - seg_output_loss: 0.2499 - val_class_output_accuracy: 0.6131 - val_class_output_loss: 1.4017 - val_loss: 1.6521 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2417
# Epoch 90/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 242ms/step - class_output_accuracy: 0.9636 - class_output_loss: 0.2226 - loss: 0.4682 - seg_output_accuracy: 0.8945 - seg_output_loss: 0.2455 - val_class_output_accuracy: 0.6085 - val_class_output_loss: 1.4030 - val_loss: 1.6534 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2418
# Epoch 91/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - class_output_accuracy: 0.9712 - class_output_loss: 0.2024 - loss: 0.4468 - seg_output_accuracy: 0.8949 - seg_output_loss: 0.2444 - val_class_output_accuracy: 0.6085 - val_class_output_loss: 1.4051 - val_loss: 1.6555 - val_seg_output_accuracy: 0.8971 - val_seg_output_loss: 0.2417
# Epoch 92/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 261ms/step - class_output_accuracy: 0.9673 - class_output_loss: 0.2050 - loss: 0.4507 - seg_output_accuracy: 0.8943 - seg_output_loss: 0.2457 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.4066 - val_loss: 1.6568 - val_seg_output_accuracy: 0.8969 - val_seg_output_loss: 0.2416
# Epoch 93/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 216ms/step - class_output_accuracy: 0.9718 - class_output_loss: 0.1978 - loss: 0.4468 - seg_output_accuracy: 0.8921 - seg_output_loss: 0.2490 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.4065 - val_loss: 1.6565 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2415
# Epoch 94/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 258ms/step - class_output_accuracy: 0.9716 - class_output_loss: 0.1950 - loss: 0.4409 - seg_output_accuracy: 0.8947 - seg_output_loss: 0.2459 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.4073 - val_loss: 1.6572 - val_seg_output_accuracy: 0.8971 - val_seg_output_loss: 0.2412
# Epoch 95/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 215ms/step - class_output_accuracy: 0.9767 - class_output_loss: 0.1853 - loss: 0.4315 - seg_output_accuracy: 0.8944 - seg_output_loss: 0.2462 - val_class_output_accuracy: 0.6094 - val_class_output_loss: 1.4086 - val_loss: 1.6585 - val_seg_output_accuracy: 0.8973 - val_seg_output_loss: 0.2411
# Epoch 96/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 236ms/step - class_output_accuracy: 0.9795 - class_output_loss: 0.1796 - loss: 0.4294 - seg_output_accuracy: 0.8929 - seg_output_loss: 0.2499 - val_class_output_accuracy: 0.6104 - val_class_output_loss: 1.4105 - val_loss: 1.6604 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2415
# Epoch 97/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 216ms/step - class_output_accuracy: 0.9820 - class_output_loss: 0.1784 - loss: 0.4252 - seg_output_accuracy: 0.8934 - seg_output_loss: 0.2469 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.4121 - val_loss: 1.6623 - val_seg_output_accuracy: 0.8971 - val_seg_output_loss: 0.2419
# Epoch 98/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 218ms/step - class_output_accuracy: 0.9770 - class_output_loss: 0.1825 - loss: 0.4252 - seg_output_accuracy: 0.8957 - seg_output_loss: 0.2427 - val_class_output_accuracy: 0.6122 - val_class_output_loss: 1.4135 - val_loss: 1.6633 - val_seg_output_accuracy: 0.8972 - val_seg_output_loss: 0.2413
# Epoch 99/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - class_output_accuracy: 0.9768 - class_output_loss: 0.1811 - loss: 0.4292 - seg_output_accuracy: 0.8935 - seg_output_loss: 0.2481 - val_class_output_accuracy: 0.6140 - val_class_output_loss: 1.4132 - val_loss: 1.6628 - val_seg_output_accuracy: 0.8974 - val_seg_output_loss: 0.2412
# training time exceeded and ending early
# training ended on epoch 99
# training time = 30.027550200621288 mins

# %%
#
# Evaluation
#
# You should evaluate both your networks for both tasks. To help generate metrics and plots, you may want to pull out the labels from the dataset
# which you could do with something like the following:
#
# y_class_test = np.concatenate([y[0] for x,y in test_class_seg.as_numpy_iterator()])
# y_seg_test = np.concatenate([y[1] for x,y in test_class_seg.as_numpy_iterator()])
#
# For evaluating the two tasks, the classification task is just like all the other classification tasks you've done this semseter and you can follow
# how these have been dealt with. For the segmentation task, one way to look at this is as a binary classification task as you're classifiying each
# pixel into foreground and background. With that in mind you could do something like this:
#
# class_preds, seg_preds = my_awesome_network.predict(test_class_seg)
# seg_preds_flat = seg_preds.reshape(-1) > 0.5 # flatten predictions, turn into boolean vector where true is fgnd and false is bkgnd
# seg_gt_flat = y_seg_test.reshape(-1) > 0.5 # same as above, but for the ground truth, need to have both as a boolean vector
# cm = sklearn.metrics.confusion_matrix(seg_gt_flat, seg_preds_flat)
#
# You could also look at other segmentation specific metrics as a way to evaluate performance

# 6. Evaluation
# Process ground truth and predictions in chunks to reduce memory usage
def evaluate_model(model, dataset, num_samples=100):
    class_preds_list = []
    seg_preds_list = []
    y_class_list = []
    y_seg_list = []

    for batch in dataset.take(num_samples // batch_size + 1):
        images, (labels, masks) = batch
        class_pred, seg_pred = model.predict(images, verbose=0)
        class_preds_list.append(class_pred)
        seg_preds_list.append(seg_pred)
        y_class_list.append(labels.numpy())
        y_seg_list.append(masks.numpy())

    class_preds = np.concatenate(class_preds_list, axis=0)[:num_samples]
    seg_preds = np.concatenate(seg_preds_list, axis=0)[:num_samples]
    y_class = np.concatenate(y_class_list, axis=0)[:num_samples]
    y_seg = np.concatenate(y_seg_list, axis=0)[:num_samples]

    return class_preds, seg_preds, y_class, y_seg

# From-Scratch Model Evaluation (Limit to 100 samples to reduce memory usage)
class_preds_scratch, seg_preds_scratch, y_class_test, y_seg_test = evaluate_model(from_scratch_model, test_class_seg, num_samples=100)

# Classification: Accuracy and Confusion Matrix
class_preds_scratch_labels = np.argmax(class_preds_scratch, axis=1)
cm_scratch = confusion_matrix(y_class_test, class_preds_scratch_labels)
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1)
ConfusionMatrixDisplay(cm_scratch).plot(ax=ax)
ax.set_title('From-Scratch Model: Classification Confusion Matrix')
plt.savefig('from_scratch_class_confusion.png')

class_accuracy_scratch = np.mean(class_preds_scratch_labels == y_class_test)

# Segmentation: IoU and Confusion Matrix
seg_preds_scratch_flat = (seg_preds_scratch.reshape(-1) > 0.5)
seg_gt_flat = (y_seg_test.reshape(-1) > 0.5)
cm_seg_scratch = confusion_matrix(seg_gt_flat, seg_preds_scratch_flat)
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1)
ConfusionMatrixDisplay(cm_seg_scratch, display_labels=['Background', 'Foreground']).plot(ax=ax)
ax.set_title('From-Scratch Model: Segmentation Confusion Matrix')
plt.savefig('from_scratch_seg_confusion.png')

# Compute IoU for Segmentation
intersection = np.logical_and(seg_preds_scratch_flat, seg_gt_flat).sum()
union = np.logical_or(seg_preds_scratch_flat, seg_gt_flat).sum()
iou_scratch = intersection / union if union > 0 else 0

# MobileNetV3Small Model Evaluation (Limit to 100 samples)
class_preds_mobile, seg_preds_mobile, y_class_test, y_seg_test = evaluate_model(mobilenet_model, test_class_seg, num_samples=100)

# Classification: Accuracy and Confusion Matrix
class_preds_mobile_labels = np.argmax(class_preds_mobile, axis=1)
cm_mobile = confusion_matrix(y_class_test, class_preds_mobile_labels)
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1)
ConfusionMatrixDisplay(cm_mobile).plot(ax=ax)
ax.set_title('MobileNetV3Small Model: Classification Confusion Matrix')
plt.savefig('mobilenet_class_confusion.png')

class_accuracy_mobile = np.mean(class_preds_mobile_labels == y_class_test)

# Segmentation: IoU and Confusion Matrix
seg_preds_mobile_flat = (seg_preds_mobile.reshape(-1) > 0.5)
cm_seg_mobile = confusion_matrix(seg_gt_flat, seg_preds_mobile_flat)
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1)
ConfusionMatrixDisplay(cm_seg_mobile, display_labels=['Background', 'Foreground']).plot(ax=ax)
ax.set_title('MobileNetV3Small Model: Segmentation Confusion Matrix')
plt.savefig('mobilenet_seg_confusion.png')

intersection = np.logical_and(seg_preds_mobile_flat, seg_gt_flat).sum()
union = np.logical_or(seg_preds_mobile_flat, seg_gt_flat).sum()
iou_mobile = intersection / union if union > 0 else 0

# Print Metrics
print("From-Scratch Model Metrics:")
print(f"Classification Accuracy: {class_accuracy_scratch:.4f}")
print(f"Segmentation IoU: {iou_scratch:.4f}")
print("\nMobileNetV3Small Model Metrics:")
print(f"Classification Accuracy: {class_accuracy_mobile:.4f}")
print(f"Segmentation IoU: {iou_mobile:.4f}")

# Visualize Segmentation Predictions (5 Samples)
fig, axs = plt.subplots(3, 5, figsize=(15, 9), layout="constrained")
for i in range(5):
    # Ground Truth Image
    batch = test_class_seg.take(1).as_numpy_iterator().next()
    axs[0, i].imshow(np.squeeze(unprocess_image(batch[0][i, ...])) / 255.0)
    axs[0, i].set_title(f'Sample {i+1}: Ground Truth Image')
    axs[0, i].axis('off')
    # Ground Truth Mask
    axs[1, i].imshow(np.squeeze(y_seg_test[i, ...]))
    axs[1, i].set_title('Ground Truth Mask')
    axs[1, i].axis('off')
    # Predicted Mask (MobileNetV3Small)
    axs[2, i].imshow(np.squeeze(seg_preds_mobile[i, ...]))
    axs[2, i].set_title('MobileNet Predicted Mask')
    axs[2, i].axis('off')
plt.savefig('segmentation_predictions.png')
# Out:
# From-Scratch Model Metrics:
# Classification Accuracy: 0.4600
# Segmentation IoU: 0.7775
#
# MobileNetV3Small Model Metrics:
# Classification Accuracy: 0.6500
# Segmentation IoU: 0.8018

# %%
# For your write-up, you should include:
# - A discussion of what pre-processing (i.e. resizing, colour conversion, augmentation, etc.) you apply to the data and why.
# - Details of two implemented methods. This should include a details of the final “from-scratch” approach and justification
#   for the chosen design, and details of changes made to MobileNetV3Small for the “fine-tuned” approach. Details on how the
#   models are trained are also to be provided.
# - An evaluation that compares the two models for the two tasks (classification and semantic segmentation). Your evaluation
#   should discuss overall model performance, how it differs between the two approaches, and include figures if/where necessary.
# - A discussion of methods that were explored to improve performance for both models and mitigate identified issues, and potentially
#   other methods that were considered but not implemented due to computational constraints. See the assignment brief for further
#   details.
# Your write-up should be supported by appropriate figures and tables. Figures and tables should have numbers and meaningful captions.
# Note that figures and tables are not included in the page limits.
#
# SEE THE ASSIGNMENT BRIEF ON CANVAS FOR MORE DETAILS AND NOTE THAT A NOTEBOOK FILE DOES NOT CONSTITUTE A VALID SUBMISSION.
# YOU SHOULD WRITE UP YOUR RESPONSE IN A SEPARATE DOCUMENT
