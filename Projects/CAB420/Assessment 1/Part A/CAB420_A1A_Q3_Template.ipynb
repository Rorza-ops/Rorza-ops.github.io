# %% [markdown]
# # CAB420 Assignment 1A Question 3: Template and Utilities Demo
# Simon Denman (s.denman@qut.edu.au)
#
# ## Overview
#
# This notebook provides a quick demo and overview of the provided utility functions to help with Assignment 1A, Question 3.
#
# It also implements the SVM that you are to compare against when responsing to the question.
#
# Please make sure you read the assignment brief on canvas, and check the FAQ for other information.
#
# **Note: File paths used in this template may need to change for your local machine. Please set these based on your local file system structure.**
#
# ## Utility Functions
#
# The following cell contains utility functions to:
# * Load the data
# * Vectorise the data
# * Plot images
# * Resize all images
# * Convert images to grayscale
#
# These are provided to assist you in developing your solution.

# %%
#
# Utility functions for CAB420, Assignment 1A, Q3
# Author: Simon Denman (s.denman@qut.edu.au)
#
from google.colab import drive
drive.mount('/content/drive')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from scipy.io import loadmat        # to load mat files
import matplotlib.pyplot as plt     # for plotting
import numpy as np                  # for reshaping, array manipulation
import cv2                          # for colour conversion
import tensorflow as tf             # for bulk image resize
import keras
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

# Load data for Q3
#  train_path: path to training data mat file
#  test_path:  path to testing data mat file
#
#  returns:    arrays for training and testing X and Y data
#
def load_data(train_path, val_path, test_path):

    # load files
    train = loadmat(train_path)
    val = loadmat(val_path)
    test = loadmat(test_path)

    # pull out training set and scale X data
    train_X = train['train_X'] / 255.0
    train_Y = train['train_y'].reshape(-1)

    # pull out validation set and scale X data
    val_X = val['val_X'] / 255.0
    val_Y = val['val_y'].reshape(-1)

    # pull out test set and scale X data
    test_X = test['test_X'] / 255.0
    test_Y = test['test_y'].reshape(-1)

    # return loaded data
    return train_X, train_Y, val_X, val_Y, test_X, test_Y

# vectorise an array of images, such that the shape is changed from {samples, width, height, channels} to
# (samples, width * height * channels)
#   images: array of images to vectorise
#
#   returns: vectorised array of images
#
def vectorise(images):
    # use numpy's reshape to vectorise the data
    return np.reshape(images, [len(images), -1])

# Plot some images and their labels. Will plot the first 100 samples in a 10x10 grid
#  x: array of images, of shape (samples, width, height, channels)
#  y: labels of the images
#
def plot_images(x, y):
    fig = plt.figure(figsize=[15, 18])
    for i in range(100):
        ax = fig.add_subplot(10, 10, i + 1)
        ax.imshow(x[i,:])
        ax.set_title(y[i])
        ax.axis('off')

# Resize an array of images
#  images:   array of images, of shape (samples, width, height, channels)
#  new_size: tuple of the new size, (new_width, new_height)
#
#  returns:  resized array of images, (samples, new_width, new_height, channels)
#
def resize(images, new_size):
    # tensorflow has an image resize funtion that can do this in bulk
    # note the conversion back to numpy after the resize
    return tf.image.resize(images, new_size).numpy()

# Convert images to grayscale
#   images:  array of colour images to convert, of size (samples, width, height, 3)
#
#   returns: array of converted images, of size (samples, width, height, 1)
#
def convert_to_grayscale(images):
    # storage for converted images
    gray = []
    images = images.numpy()
    # loop through images
    for i in range(len(images)):
        # convert each image using openCV
        gray.append(cv2.cvtColor(images[i,:], cv2.COLOR_BGR2GRAY))
    # pack converted list as an array and return
    return np.expand_dims(np.array(gray), axis = -1)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Utility Function Demonstration
#
# The following presents a brief demonstration of the utility functions. These portions of code do not form part of the template, or solution, and could be commented out/removed.
#
# ### Data Loading
#
# Load the data, and visualise images.

# %%
train_X, train_Y, val_X, val_Y, test_X, test_Y = load_data('/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_train.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_validation.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_test.mat')

# check shape of data
print(train_X.shape)
print(train_Y.shape)
print(val_X.shape)
print(val_Y.shape)
print(test_X.shape)
print(test_Y.shape)

# visualise images as a sanity check
plot_images(train_X, train_Y)
# Out:
# (1000, 32, 32, 3)
# (1000,)
# (1000, 32, 32, 3)
# (1000,)
# (10000, 32, 32, 3)
# (10000,)

# %% [markdown]
# ### Vectorise Data
#
# To train an SVM, each sample needs to be a vector rather than an image.

# %%
train_vector_X = vectorise(train_X)
val_vector_X = vectorise(val_X)
test_vector_X = vectorise(test_X)
print(train_vector_X.shape)
print(val_vector_X.shape)
print(test_vector_X.shape)
# Out:
# (1000, 3072)
# (1000, 3072)
# (10000, 3072)

# %% [markdown]
# ### Conversion and Resizing
#
# You may wish to either:
# * Resize images
# * Convert images to grayscale
#
# Two functions are provided to do this, and can be used in combination as shown below.

# %%
train_X_small = convert_to_grayscale(resize(train_X, (20, 20)))
print(train_X_small.shape)
plot_images(train_X_small, train_Y)
# Out:
# (1000, 20, 20, 1)

# %% [markdown]
# ### Measuring Time
#
# There are a lot of ways to measure time in python. A simple one is to use ``process_time`` within the ``time`` package. This will simply measure the ellapsed process time in seconds. We can use ths to measure individual parts of our code as follows:

# %%
# import process_time
from time import process_time

# get a start time
time_1 = process_time()

# do some stuff, in this case we'll just load some data
train_X, train_Y,val_X, val_Y, test_X, test_Y = load_data('/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_train.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_validation.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_test.mat')

# get the end time of our first lot of "stuff"
time_2 = process_time()

# do some other stuff
train_X_small = convert_to_grayscale(resize(train_X, (20, 20)))

# get the end time of our first lot of "stuff"
time_3 = process_time()

# the time it took to do "our stuff" is just the difference between the start and end times
print('Time to load data:   %f seconds' % (time_2 - time_1))
print('Time to resize data: %f seconds' % (time_3 - time_2))
# Out:
# Time to load data:   0.161526 seconds
# Time to resize data: 0.025258 seconds

# %% [markdown]
# ## Question 3 Template
#
# The following provides a starting point for your solution. It trains the SVM that you are to compare your trained DCNNs against, and measures the time taken to train this SVM, and to perform inference with the train and test sets.
#
# This does not measure the performance of the SVM - you will need to implement this as part of your solution.

# %%
from sklearn.svm import SVC
from time import process_time

# load data
train_X, train_Y,val_X, val_Y, test_X, test_Y = load_data('/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_train.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_validation.mat', '/content/drive/MyDrive/CAB420/ASSESSMENTS/ASSESSMENT_1A/Q3/q3_test.mat')
train_YY = to_categorical(train_Y, num_classes=10)
val_YY = to_categorical(val_Y, num_classes=10)
test_YY = to_categorical(test_Y, num_classes=10)
# any resize, colour change, etc, would go here
# if you do anything, do the same thing to the training, validation, and test sets

# vectorise data
# If you do any resize, reshape, etc of the data prior to putting this into your DCNN, change this code to
# vectorise that verison of the data. The same data should be used by all models for a fair comparison; though
# you will only vectorise the data for the SVM (i.e. the DCNN will get the data as images).
train_vector_X = vectorise(train_X)
val_vector_X = vectorise(val_X)
test_vector_X = vectorise(test_X)
def eval_SVM_model(model, X_train, Y_train, X_test, Y_test):
    fig = plt.figure(figsize=[25, 8])
    ax = fig.add_subplot(1, 2, 1)
    conf = ConfusionMatrixDisplay.from_estimator(model, X_train, Y_train, normalize='true', ax=ax)
    conf.ax_.set_title('Training Set Performance: %1.3f' % (sum(model.predict(X_train) == Y_train)/len(Y_train)));
    ax = fig.add_subplot(1, 2, 2)
    conf = ConfusionMatrixDisplay.from_estimator(model, X_test, Y_test, normalize='true', ax=ax)
    conf.ax_.set_title('Testing Set Performance: %1.3f' % (sum(model.predict(X_test) == Y_test)/len(Y_test)));
    print(classification_report(Y_test, model.predict(X_test)))

# train the SVM
# Note that you are not required to tune the SVM, just use it as it is. This also means that we do not need the validation
# set for the SVM as we're not selecting hyper-parameters
# measure the start time of training
svm_train_start = process_time()
# run the training - note that you don't need to change any parameters here except potentially for the input data is you
# resize, change colour, etc
svm = SVC(C = 1, kernel = 'linear').fit(train_vector_X, train_Y)
# record the end time of the training
svm_train_end = process_time()
# predict on the training set
train_predictions = svm.predict(train_vector_X)
# measure of the time of the training set prediction
svm_train_pred_end = process_time()
# predict on the test set
test_predictions = svm.predict(test_vector_X)
# measure the end time on the prediction of the test set
svm_test_pred_end = process_time()

# check how long the SVM took to train
svm_train_time = svm_train_end - svm_train_start
# check how long the SVM took to perform inference on the training set
svm_inference_train_time = svm_train_pred_end - svm_train_end
# check how long the SVM took to perform inference on the testing set
svm_inference_test_time = svm_test_pred_end - svm_train_pred_end
# print some times
eval_SVM_model(svm, train_vector_X, train_Y, test_vector_X, test_Y)
print('Training Time: %f\nInference Time (training set): %f\nInference Time (testing set): %f' % \
      (svm_train_time, svm_inference_train_time, svm_inference_test_time))

# evaluate SVM
# here you can insert whatever evaluation metrics you feel are appropriate, though F1 and a confusion matrix would be a fair
# option
# Out:
#               precision    recall  f1-score   support
#
#            0       0.10      0.14      0.12       686
#            1       0.29      0.41      0.34      1969
#            2       0.21      0.24      0.22      1629
#            3       0.19      0.17      0.18      1108
#            4       0.13      0.12      0.12       966
#            5       0.13      0.10      0.11       902
#            6       0.10      0.06      0.08       765
#            7       0.11      0.08      0.09       757
#            8       0.08      0.04      0.05       603
#            9       0.11      0.08      0.10       615
#
#     accuracy                           0.19     10000
#    macro avg       0.14      0.14      0.14     10000
# weighted avg       0.17      0.19      0.17     10000
#
# Training Time: 4.374406
# Inference Time (training set): 1.212074
# Inference Time (testing set): 11.165103

# %%
train_X_inverted = 1.0 - train_X
print("inverted",train_X_inverted.shape)
plot_images(train_X_inverted, train_Y)

rotate_layer_10 = tf.keras.layers.RandomRotation(factor=10/360.0)
train_X_rotated10 = rotate_layer_10(train_X)
print("rotated",train_X_rotated10.shape)
plot_images(train_X_rotated10, train_Y)

rotate_layer_20 = tf.keras.layers.RandomRotation(factor=20/360.0)
train_X_rotated20 = rotate_layer_20(train_X)
print("rotated",train_X_rotated20.shape)
plot_images(train_X_rotated20, train_Y)

rotate_layer_30 = tf.keras.layers.RandomRotation(factor=30/360.0)
train_X_rotated30 = rotate_layer_30(train_X)
print("rotated",train_X_rotated30.shape)
plot_images(train_X_rotated30, train_Y)

train_X_rotated30_inverted = 1.0 - train_X_rotated30
print("rotated gray scale",train_X_rotated30_inverted.shape)
plot_images(train_X_rotated30_inverted, train_Y)
# Out:
# inverted (1000, 32, 32, 3)
# rotated (1000, 32, 32, 3)
# rotated (1000, 32, 32, 3)
# rotated (1000, 32, 32, 3)
# rotated gray scale (1000, 32, 32, 3)

# %%
# develop, evaluate and compare DCNNs
#
# You should create one DCNN which you will train from scratch, and then add augmentation to this and train it again.
# Use whatever augmentation you feel is appropraite.
#
# For your DCNN design, feel free to borrow networks from pracs and lecture examples. The network does not need to be
# overly complex, but you should briefly explain your selection of this model. You should avoid networks so simple
# that they perform very badly. Look at the lecture notes and the sort of simple DCNNs we've created as a guide. With
# respect to training time, there is no minimum or maximum training time, but you should either:
#  - Train both your models to convergence, noting that this may take different numbers of epochs
#  - Train your networks for the same period of time, ensuring that this time is sufficient for at least one to converge
# Keep in mind that with the very small training set, you may need to increase the number of epochs compared to what we
# see in the lecture examples

## EVALUATION FUNCTION
def eval_model(model, train, train_y, test, test_y):
    fig = plt.figure(figsize=[20, 8])
    ax = fig.add_subplot(1, 2, 1)
    pred = model.predict(train, verbose=False);
    indexes = tf.argmax(pred, axis=1)
    gt_idx = tf.argmax(train_y, axis=1)
    confusion_mtx = tf.math.confusion_matrix(gt_idx, indexes)
    sns.heatmap(confusion_mtx, xticklabels=range(10), yticklabels=range(10), annot=True, fmt='g', ax=ax)
    ax.set_title('Training, F1 Score: %f' % f1_score(gt_idx, indexes, average='weighted'))
    ax = fig.add_subplot(1, 2, 2)
    pred = model.predict(test, verbose=False);
    indexes = tf.argmax(pred, axis=1)
    gt_idx = tf.argmax(test_y, axis=1)
    confusion_mtx = tf.math.confusion_matrix(gt_idx, indexes)
    sns.heatmap(confusion_mtx, xticklabels=range(10), yticklabels=range(10), annot=True, fmt='g', ax=ax)
    ax.set_title('Testing, F1 Score: %f' % f1_score(gt_idx, indexes, average='weighted'))

# %%
## NO AUGMENTATION
# Model parameters
from time import process_time
inputs = keras.Input(shape=(32, 32, 3), name='img')
x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(inputs)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Build model
model_vgg = keras.Model(inputs=inputs, outputs=outputs, name='digit_vgg')
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
model_vgg.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
DCNN_train_start = process_time()
history = model_vgg.fit(train_X, train_YY, batch_size=32, epochs=100, validation_data=(val_X, val_YY),callbacks=[early_stop])
DCNN_train_end = process_time()
DCNN_train_time = DCNN_train_end - DCNN_train_start

# PLOTS
fig = plt.figure(figsize=[20, 6])
ax = fig.add_subplot(1, 2, 1)
ax.plot(history.history['loss'], label="Training Loss")
ax.plot(history.history['val_loss'], label="Validation Loss")
ax.legend()
ax = fig.add_subplot(1, 2, 2)
ax.plot(history.history['accuracy'], label="Training Accuracy")
ax.plot(history.history['val_accuracy'], label="Validation Accuracy")
ax.legend()
DCNN_test_start = process_time()
eval_model(model_vgg, train_X, train_YY, test_X, test_YY)
DCNN_test_end = process_time()
DCNN_test_time = DCNN_test_end - DCNN_test_start
print('Training Time: %f' % (DCNN_train_time))
print('Test Time: %f' % (DCNN_test_time))
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 587ms/step - accuracy: 0.1365 - loss: 9.2153 - val_accuracy: 0.0920 - val_loss: 6.3538
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.1243 - loss: 6.2353 - val_accuracy: 0.1150 - val_loss: 3.5066
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.1701 - loss: 2.4109 - val_accuracy: 0.0670 - val_loss: 2.5286
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.1654 - loss: 2.2842 - val_accuracy: 0.1070 - val_loss: 2.6497
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.1950 - loss: 2.2526 - val_accuracy: 0.1970 - val_loss: 2.6872
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2100 - loss: 2.2361 - val_accuracy: 0.1940 - val_loss: 2.3976
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2322 - loss: 2.1805 - val_accuracy: 0.2030 - val_loss: 2.3894
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2534 - loss: 2.0921 - val_accuracy: 0.1510 - val_loss: 3.2474
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2871 - loss: 1.9997 - val_accuracy: 0.2290 - val_loss: 2.2965
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2740 - loss: 2.0231 - val_accuracy: 0.2930 - val_loss: 2.0555
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3428 - loss: 1.8940 - val_accuracy: 0.1350 - val_loss: 2.7703
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3874 - loss: 1.7936 - val_accuracy: 0.3490 - val_loss: 1.8978
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.3706 - loss: 1.7974 - val_accuracy: 0.3540 - val_loss: 1.8637
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3996 - loss: 1.6997 - val_accuracy: 0.3780 - val_loss: 1.8259
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4769 - loss: 1.5523 - val_accuracy: 0.3730 - val_loss: 1.9228
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4851 - loss: 1.5035 - val_accuracy: 0.3940 - val_loss: 1.9096
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4880 - loss: 1.5112 - val_accuracy: 0.2310 - val_loss: 2.7621
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5152 - loss: 1.4051 - val_accuracy: 0.4390 - val_loss: 1.8871
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5455 - loss: 1.2444 - val_accuracy: 0.5380 - val_loss: 1.5071
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6325 - loss: 1.0851 - val_accuracy: 0.5350 - val_loss: 1.5729
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6488 - loss: 0.9826 - val_accuracy: 0.5990 - val_loss: 1.3968
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6964 - loss: 0.9522 - val_accuracy: 0.6060 - val_loss: 1.2847
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6966 - loss: 0.9297 - val_accuracy: 0.4180 - val_loss: 1.9270
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7061 - loss: 0.8405 - val_accuracy: 0.5700 - val_loss: 1.5291
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6748 - loss: 1.0127 - val_accuracy: 0.6790 - val_loss: 1.3181
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7183 - loss: 0.8888 - val_accuracy: 0.6100 - val_loss: 1.3926
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7857 - loss: 0.6538 - val_accuracy: 0.7280 - val_loss: 1.0903
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7928 - loss: 0.5512 - val_accuracy: 0.6980 - val_loss: 1.1286
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8200 - loss: 0.5114 - val_accuracy: 0.7370 - val_loss: 1.1855
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8472 - loss: 0.4716 - val_accuracy: 0.7470 - val_loss: 1.0860
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8741 - loss: 0.3572 - val_accuracy: 0.5200 - val_loss: 2.1597
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8395 - loss: 0.5027 - val_accuracy: 0.6660 - val_loss: 1.3946
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8568 - loss: 0.4138 - val_accuracy: 0.7490 - val_loss: 1.1866
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8766 - loss: 0.3714 - val_accuracy: 0.7430 - val_loss: 1.1048
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8635 - loss: 0.3479 - val_accuracy: 0.7340 - val_loss: 1.3175
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8906 - loss: 0.3168 - val_accuracy: 0.6900 - val_loss: 1.3663
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8768 - loss: 0.3636 - val_accuracy: 0.7100 - val_loss: 1.2058
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8965 - loss: 0.2991 - val_accuracy: 0.7210 - val_loss: 1.2892
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8833 - loss: 0.3029 - val_accuracy: 0.7780 - val_loss: 1.1440
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9012 - loss: 0.2846 - val_accuracy: 0.7720 - val_loss: 1.1168
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9447 - loss: 0.1978 - val_accuracy: 0.8090 - val_loss: 1.0818
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9261 - loss: 0.1987 - val_accuracy: 0.7870 - val_loss: 1.1512
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9569 - loss: 0.1320 - val_accuracy: 0.8220 - val_loss: 1.0301
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9543 - loss: 0.1500 - val_accuracy: 0.7000 - val_loss: 1.2874
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9247 - loss: 0.2281 - val_accuracy: 0.7780 - val_loss: 1.2715
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8768 - loss: 0.3809 - val_accuracy: 0.7540 - val_loss: 1.1190
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9107 - loss: 0.2601 - val_accuracy: 0.7630 - val_loss: 1.2651
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9110 - loss: 0.2832 - val_accuracy: 0.7580 - val_loss: 1.2274
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9467 - loss: 0.1564 - val_accuracy: 0.8040 - val_loss: 1.1901
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9580 - loss: 0.1123 - val_accuracy: 0.7870 - val_loss: 1.2817
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9481 - loss: 0.1400 - val_accuracy: 0.7680 - val_loss: 1.3749
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9543 - loss: 0.1506 - val_accuracy: 0.7740 - val_loss: 1.3185
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9560 - loss: 0.1449 - val_accuracy: 0.7900 - val_loss: 1.3678
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9497 - loss: 0.1591 - val_accuracy: 0.8120 - val_loss: 1.3071
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9430 - loss: 0.1465 - val_accuracy: 0.7410 - val_loss: 1.6541
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9461 - loss: 0.1410 - val_accuracy: 0.7820 - val_loss: 1.2911
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9522 - loss: 0.1403 - val_accuracy: 0.7890 - val_loss: 1.4032
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9523 - loss: 0.1242 - val_accuracy: 0.7910 - val_loss: 1.2615
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9732 - loss: 0.0925 - val_accuracy: 0.8090 - val_loss: 1.2672
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9727 - loss: 0.0931 - val_accuracy: 0.7860 - val_loss: 1.5585
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9722 - loss: 0.0949 - val_accuracy: 0.7200 - val_loss: 1.6523
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9540 - loss: 0.1405 - val_accuracy: 0.7610 - val_loss: 1.5768
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9733 - loss: 0.0968 - val_accuracy: 0.8020 - val_loss: 1.5305
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9656 - loss: 0.1102 - val_accuracy: 0.7950 - val_loss: 1.4773
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9525 - loss: 0.1366 - val_accuracy: 0.7900 - val_loss: 1.4465
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9603 - loss: 0.1191 - val_accuracy: 0.7600 - val_loss: 1.6627
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9534 - loss: 0.1518 - val_accuracy: 0.6580 - val_loss: 2.1412
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9468 - loss: 0.1508 - val_accuracy: 0.7880 - val_loss: 1.3868
# Training Time: 52.544055
# Test Time: 6.528774

# %%
## WITH AUGMENTATION
# Model parameters
from time import process_time
inputs = keras.Input(shape=(32, 32, 3), name='img')
x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(inputs)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Build model
model_vgg2 = keras.Model(inputs=inputs, outputs=outputs, name='digit_vgg')
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
model_vgg2.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
DCNNA_train_start = process_time()
history = model_vgg2.fit(train_X_rotated30_inverted, train_YY, batch_size=32, epochs=100, validation_data=(val_X, val_YY),callbacks=[early_stop])
DCNNA_train_end = process_time()
DCNNA_train_time = DCNNA_train_end - DCNNA_train_start

# PLOTS
fig = plt.figure(figsize=[20, 6])
ax = fig.add_subplot(1, 2, 1)
ax.plot(history.history['loss'], label="Training Loss")
ax.plot(history.history['val_loss'], label="Validation Loss")
ax.legend()
ax = fig.add_subplot(1, 2, 2)
ax.plot(history.history['accuracy'], label="Training Accuracy")
ax.plot(history.history['val_accuracy'], label="Validation Accuracy")
ax.legend()
DCNNA_test_start = process_time()
eval_model(model_vgg2, train_X_rotated30_inverted, train_YY, test_X, test_YY)
DCNNA_test_end = process_time()
DCNNA_test_time = DCNNA_test_end - DCNNA_test_start
print('Training Time: %f' % (DCNNA_train_time))
print('Test Time: %f' % (DCNNA_test_time))
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 238ms/step - accuracy: 0.1107 - loss: 10.2581 - val_accuracy: 0.0790 - val_loss: 4.0089
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.1538 - loss: 4.3119 - val_accuracy: 0.1930 - val_loss: 5.9086
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1610 - loss: 2.9468 - val_accuracy: 0.1930 - val_loss: 4.9289
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1841 - loss: 2.2983 - val_accuracy: 0.1750 - val_loss: 4.7291
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1937 - loss: 2.2802 - val_accuracy: 0.1540 - val_loss: 5.1240
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1872 - loss: 2.2789 - val_accuracy: 0.1520 - val_loss: 5.5556
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1616 - loss: 2.2838 - val_accuracy: 0.1510 - val_loss: 6.1611
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1903 - loss: 2.2684 - val_accuracy: 0.1380 - val_loss: 6.9453
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1826 - loss: 2.2804 - val_accuracy: 0.1880 - val_loss: 4.2449
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.1670 - loss: 2.2685 - val_accuracy: 0.1550 - val_loss: 5.7911
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.1889 - loss: 2.2682 - val_accuracy: 0.1810 - val_loss: 4.7124
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1737 - loss: 2.2645 - val_accuracy: 0.1710 - val_loss: 3.9315
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.1963 - loss: 2.2438 - val_accuracy: 0.1510 - val_loss: 3.0602
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1982 - loss: 2.2706 - val_accuracy: 0.1490 - val_loss: 2.5895
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.1906 - loss: 2.2435 - val_accuracy: 0.1580 - val_loss: 2.3499
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.1728 - loss: 2.2450 - val_accuracy: 0.1590 - val_loss: 2.3063
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.2009 - loss: 2.2392 - val_accuracy: 0.1900 - val_loss: 2.2697
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.1917 - loss: 2.2478 - val_accuracy: 0.1730 - val_loss: 2.3689
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.1905 - loss: 2.2429 - val_accuracy: 0.1920 - val_loss: 2.3103
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.1778 - loss: 2.2499 - val_accuracy: 0.1890 - val_loss: 2.2765
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.1805 - loss: 2.2483 - val_accuracy: 0.1870 - val_loss: 2.2615
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.1831 - loss: 2.2343 - val_accuracy: 0.1930 - val_loss: 2.2478
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.1952 - loss: 2.2300 - val_accuracy: 0.1930 - val_loss: 2.2554
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1740 - loss: 2.2510 - val_accuracy: 0.1940 - val_loss: 2.2477
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.1644 - loss: 2.2466 - val_accuracy: 0.1930 - val_loss: 2.2468
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.1857 - loss: 2.2210 - val_accuracy: 0.1930 - val_loss: 2.2484
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1726 - loss: 2.2305 - val_accuracy: 0.1940 - val_loss: 2.2460
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.1947 - loss: 2.2311 - val_accuracy: 0.1920 - val_loss: 2.2489
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1696 - loss: 2.2305 - val_accuracy: 0.1880 - val_loss: 2.2474
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.1837 - loss: 2.2074 - val_accuracy: 0.1940 - val_loss: 2.2392
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.1997 - loss: 2.2078 - val_accuracy: 0.1900 - val_loss: 2.3058
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1828 - loss: 2.2461 - val_accuracy: 0.1920 - val_loss: 2.3002
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2048 - loss: 2.2137 - val_accuracy: 0.1930 - val_loss: 2.2443
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2018 - loss: 2.2223 - val_accuracy: 0.1930 - val_loss: 2.2430
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1773 - loss: 2.2388 - val_accuracy: 0.1920 - val_loss: 2.2401
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.1897 - loss: 2.2310 - val_accuracy: 0.1930 - val_loss: 2.2356
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.1816 - loss: 2.2142 - val_accuracy: 0.1930 - val_loss: 2.1875
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1943 - loss: 2.1970 - val_accuracy: 0.1940 - val_loss: 2.1832
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1811 - loss: 2.2044 - val_accuracy: 0.1940 - val_loss: 2.5052
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1842 - loss: 2.1890 - val_accuracy: 0.1920 - val_loss: 2.2201
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.1708 - loss: 2.2027 - val_accuracy: 0.1930 - val_loss: 2.1741
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1755 - loss: 2.2036 - val_accuracy: 0.1940 - val_loss: 2.1741
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.1816 - loss: 2.1927 - val_accuracy: 0.1920 - val_loss: 2.1923
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.1974 - loss: 2.1823 - val_accuracy: 0.1530 - val_loss: 2.3116
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.2084 - loss: 2.2379 - val_accuracy: 0.2380 - val_loss: 2.1425
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2209 - loss: 2.1391 - val_accuracy: 0.2330 - val_loss: 2.2002
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2204 - loss: 2.1178 - val_accuracy: 0.2520 - val_loss: 2.1550
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2282 - loss: 2.1490 - val_accuracy: 0.2350 - val_loss: 2.1828
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2295 - loss: 2.1469 - val_accuracy: 0.2510 - val_loss: 2.1607
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2282 - loss: 2.1419 - val_accuracy: 0.2720 - val_loss: 2.1137
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2250 - loss: 2.1249 - val_accuracy: 0.2310 - val_loss: 2.1899
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.2642 - loss: 2.0671 - val_accuracy: 0.2710 - val_loss: 2.0964
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.2373 - loss: 2.1306 - val_accuracy: 0.2830 - val_loss: 2.0978
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2340 - loss: 2.0956 - val_accuracy: 0.2540 - val_loss: 2.1177
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2177 - loss: 2.1187 - val_accuracy: 0.2450 - val_loss: 2.2022
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.2259 - loss: 2.0792 - val_accuracy: 0.1660 - val_loss: 2.2343
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.2622 - loss: 2.0764 - val_accuracy: 0.2520 - val_loss: 2.0831
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2611 - loss: 2.1392 - val_accuracy: 0.1910 - val_loss: 2.1920
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.2049 - loss: 2.2742 - val_accuracy: 0.2140 - val_loss: 2.3213
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.2500 - loss: 2.1286 - val_accuracy: 0.2440 - val_loss: 2.1522
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2450 - loss: 2.1662 - val_accuracy: 0.2670 - val_loss: 2.0976
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3077 - loss: 2.0244 - val_accuracy: 0.2430 - val_loss: 2.1260
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.2751 - loss: 2.1324 - val_accuracy: 0.2460 - val_loss: 2.1018
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2589 - loss: 2.0678 - val_accuracy: 0.2890 - val_loss: 2.0996
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.2897 - loss: 2.0055 - val_accuracy: 0.2380 - val_loss: 2.1433
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.2440 - loss: 2.0934 - val_accuracy: 0.2600 - val_loss: 2.2339
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3060 - loss: 1.9925 - val_accuracy: 0.2370 - val_loss: 2.8458
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3023 - loss: 1.9743 - val_accuracy: 0.2510 - val_loss: 2.8505
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.2865 - loss: 1.9865 - val_accuracy: 0.2530 - val_loss: 2.1502
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.3061 - loss: 1.9870 - val_accuracy: 0.1700 - val_loss: 2.1909
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2898 - loss: 1.9776 - val_accuracy: 0.2250 - val_loss: 2.2404
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.2760 - loss: 2.0598 - val_accuracy: 0.2900 - val_loss: 2.0222
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3210 - loss: 1.8877 - val_accuracy: 0.2940 - val_loss: 1.9750
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.3212 - loss: 1.8566 - val_accuracy: 0.2700 - val_loss: 2.8473
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3084 - loss: 2.0578 - val_accuracy: 0.2060 - val_loss: 3.1273
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.2864 - loss: 1.9261 - val_accuracy: 0.3020 - val_loss: 2.0285
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2844 - loss: 1.9195 - val_accuracy: 0.3240 - val_loss: 2.0093
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3489 - loss: 1.8394 - val_accuracy: 0.3230 - val_loss: 2.0753
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.3349 - loss: 1.8872 - val_accuracy: 0.3860 - val_loss: 1.9407
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.3565 - loss: 1.7656 - val_accuracy: 0.3890 - val_loss: 1.9042
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.3909 - loss: 1.7201 - val_accuracy: 0.3760 - val_loss: 2.6016
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4182 - loss: 1.6206 - val_accuracy: 0.3800 - val_loss: 2.2473
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3912 - loss: 1.7544 - val_accuracy: 0.2610 - val_loss: 2.1027
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.3880 - loss: 1.6217 - val_accuracy: 0.4280 - val_loss: 2.2730
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4304 - loss: 1.5872 - val_accuracy: 0.3930 - val_loss: 1.8312
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4407 - loss: 1.5396 - val_accuracy: 0.4750 - val_loss: 1.6394
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4545 - loss: 1.5043 - val_accuracy: 0.5120 - val_loss: 1.8122
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4941 - loss: 1.4412 - val_accuracy: 0.5300 - val_loss: 1.7352
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5070 - loss: 1.3936 - val_accuracy: 0.4740 - val_loss: 1.9880
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.5205 - loss: 1.3577 - val_accuracy: 0.5840 - val_loss: 1.4630
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5104 - loss: 1.3472 - val_accuracy: 0.5390 - val_loss: 1.3719
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5350 - loss: 1.2836 - val_accuracy: 0.5360 - val_loss: 1.7007
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5544 - loss: 1.2843 - val_accuracy: 0.3890 - val_loss: 4.7010
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5755 - loss: 1.1352 - val_accuracy: 0.5550 - val_loss: 2.0190
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5811 - loss: 1.1404 - val_accuracy: 0.5650 - val_loss: 1.4937
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6163 - loss: 1.0480 - val_accuracy: 0.6010 - val_loss: 1.4163
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6086 - loss: 1.1407 - val_accuracy: 0.6020 - val_loss: 1.4822
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6282 - loss: 1.0746 - val_accuracy: 0.6190 - val_loss: 1.4639
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6468 - loss: 0.9704 - val_accuracy: 0.5930 - val_loss: 1.3832
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6540 - loss: 0.9552 - val_accuracy: 0.6050 - val_loss: 1.5213
# Training Time: 58.721334
# Test Time: 5.787250

# %%
# For your write-up, you should include:
# - briefly mention any pre-processing you did and why
# - outline your network design, and training approach. The discussion of training should note how long the model was trained
#   for, and if it converged. If you observe the non-augmented and augmented networks training at different rates, discuss that
#   here
# - outline your data augmentation, and briefly justify why these methods were chosen.
# - an evaluation and comparison of three models, which should highlight any differences observed between the models, and the
#   inference time of the three models
# Your write-up should be supported by appropriate figures and tables. Figures and tables should have numbers and meaningful captions.
# Note that figures and tables are not included in the page limits.
#
# SEE THE ASSIGNMENT BRIEF ON CANVAS FOR MORE DETAILS AND NOTE THAT A NOTEBOOK FILE DOES NOT CONSTITUTE A VALID SUBMISSION.
# YOU SHOULD WRITE UP YOUR RESPONSE IN A SEPARATE DOCUMENT
